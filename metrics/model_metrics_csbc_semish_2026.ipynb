# %% [markdown]
# # Métricas do sistemas
# ---

# %% [markdown]
# ### Bibliotecas
#
# ---
#
# Caso não consiga instalar execute `pip install -r requirements.txt` no terminal

# %%
# !uv pip install -r ../requirements.txt
# Out:
# Using Python 3.14.3 environment at: /home/victorhugo/obi-benchmarking/.venv
# Checked 10 packages in 181ms

# %%
from pathlib import Path
import matplotlib.pyplot as plt
import pandas as pd
import json
import numpy as np
import re
from IPython.display import display

# %%
path_database = Path("../database")
questions_path = []
        
for folder in list(path_database.iterdir()):
    print(folder)
    if folder.is_dir():
        questions_path.append(folder)
        
problems = []
questions_name = []
for question_path in questions_path:
    questions_name.append(question_path.name)
    problems.append(json.loads(Path(question_path / "problem.json").read_text(encoding="utf-8")))
# Out:
# ../database/Gomoku
# ../database/Jogo da Vida
# ../database/Muro
# ../database/Lâmpadas do hotel
# ../database/Chinelos
# ../database/Hotel
# ../database/Jogo dos copos
# ../database/Carnaval
# ../database/Tiro ao Alvo
# ../database/Transportes
# ../database/Álbum da copa
# ../database/Jogo de Dominós
# ../database/Arco e flecha
# ../database/Quadrado Mágico
# ../database/Quase primo
# ../database/Lâmpadas
# ../database/Caça ao Tesouro_2002
# ../database/Rodovia_2013
# ../database/Coleção de Upas
# ../database/Cinema
# ../database/Fila
# ../database/Montanha
# ../database/Chuva
# ../database/Festa olímpica
# ../database/Pô, que mão
# ../database/Relógio
# ../database/Torre
# ../database/Mesa redonda
# ../database/Sorvete
# ../database/Expressões
# ../database/Mancha
# ../database/Direção
# ../database/Nova avenida
# ../database/Telescópio
# ../database/Game Show
# ../database/Manchas de pele
# ../database/Temperatura Lunar
# ../database/Castelos da Nlogônia
# ../database/Matriz Escada
# ../database/Pedágio_2002
# ../database/Fusões
# ../database/Capitais
# ../database/Falta uma
# ../database/Sanduíche
# ../database/Blefe
# ../database/Tabela do campeonato
# ../database/Clube dos Cinco
# ../database/Piso da escola
# ../database/Caravana
# ../database/Ônibus
# ../database/Chocolate_2012
# ../database/Chocolate em barra
# ../database/Altas Aventuras
# ../database/Jogo dos Pinos
# ../database/Fechadura
# ../database/Sr. Toupeira
# ../database/Sr. Sapo
# ../database/Fita Colorida
# ../database/Ponto do meio
# ../database/Ogro_2024
# ../database/Pirâmide_2022
# ../database/Game-10
# ../database/Restaurante de pizza
# ../database/Zip
# ../database/Consecutivos
# ../database/Dança de Formatura
# ../database/Estrada
# ../database/Duplas de tênis
# ../database/Show
# ../database/Loteria
# ../database/Cubo Preto
# ../database/Robô
# ../database/Etiquetas
# ../database/Campeonato
# ../database/Dominó_2001
# ../database/Reduzindo detalhes em um mapa
# ../database/Caminho das Pontes
# ../database/Botas Trocadas
# ../database/VAR
# ../database/Dona Lesma
# ../database/Frequencia na aula
# ../database/Salada de Frutas
# ../database/Ciclovias
# ../database/Pulo do Gato
# ../database/Semente
# ../database/Vice-campeão
# ../database/Tanque de combustível
# ../database/Candidatas
# ../database/Toca do Saci
# ../database/Dígitos
# ../database/Caminhos do reino
# ../database/Cartas
# ../database/Flíper
# ../database/Drone de Entrega
# ../database/problems_of_the_obi.txt
# ../database/Aeroporto
# ../database/Leilão
# ../database/Busca na Internet
# ../database/Mapa
# ../database/Medalhas
# ../database/Construtora
# ../database/Jogo
# ../database/Maximin
# ../database/model_problem.json
# ../database/Carro elétrico
# ../database/Dario e Xerxes
# ../database/Retas
# ../database/Viagem
# ../database/Soma
# ../database/Estoque
# ../database/Recibo de Compra
# ../database/Chaves
# ../database/Caverna de Ordinskaya
# ../database/Barcos da Nlogônia
# ../database/Frete
# ../database/Teste de redação
# ../database/Tacos de bilhar
# ../database/Bolas
# ../database/Prêmio
# ../database/Falha de segurança
# ../database/Bombom
# ../database/Câmara de Compensação
# ../database/Tira-teima
# ../database/Taxa
# ../database/Atlanta
# ../database/Fuga com helicóptero
# ../database/Pirâmide
# ../database/Dominó Nlogônico
# ../database/Atletismo copy
# ../database/Wifi
# ../database/Fila_2015
# ../database/Ilhas
# ../database/Grand Prix da Nlogônia
# ../database/Retângulo
# ../database/Passa Bolinha
# ../database/Frequência
# ../database/Lençol
# ../database/Subcadeias
# ../database/Quadrado
# ../database/Calculando
# ../database/Ogro_2021
# ../database/Sequência
# ../database/Xadrez
# ../database/Oficina Mecânica
# ../database/Cinco
# ../database/Quebra-cabeça
# ../database/Trem da mina
# ../database/Dominó
# ../database/Troféu
# ../database/Decifra
# ../database/Calçada Imperial
# ../database/Tesouro
# ../database/Relógios
# ../database/Cabo de guerra
# ../database/Toupeira
# ../database/Tradutor alienígena
# ../database/Copa
# ../database/Corredor
# ../database/Quadrado_2014
# ../database/Código de Compressão
# ../database/Linhas de Ônibus
# ../database/Concurso_2024
# ../database/Câmeras
# ../database/Passatempo
# ../database/Nota esquecida
# ../database/Torre de Dados
# ../database/Sequência Secreta
# ../database/Elevador
# ../database/Cortando o Papel
# ../database/Prefixo
# ../database/Intervalo Distinto
# ../database/Parcelamento sem juros
# ../database/Torneio de tênis
# ../database/Colchão
# ../database/Gincana_2016
# ../database/Teleférico
# ../database/Catálogo de Músicas
# ../database/Jogo de Tabuleiro
# ../database/Fuga
# ../database/Cubo e quadrado
# ../database/Visita entre cidades
# ../database/Jardim de infância
# ../database/Prêmio do Milhão
# ../database/Móbile_2015
# ../database/Detetive
# ../database/Concatena Dígitos
# ../database/Jogo do Preto e Branco
# ../database/Musical
# ../database/Supermercado
# ../database/PacMan
# ../database/Fotografia
# ../database/Baralho
# ../database/Floresta
# ../database/Aplicativo de Calorias
# ../database/A idade de Dona Mônica
# ../database/Receita de Bolo
# ../database/Dona Formiga
# ../database/Quadrado Mágico_2011
# ../database/Trio de Palitinhos
# ../database/Chuva_2022
# ../database/Setas
# ../database/Hotel Nlogônia
# ../database/Jogo da Memória
# ../database/Caminho
# ../database/Placas de Carro
# ../database/Tempo de resposta
# ../database/Avenida
# ../database/Dobradura
# ../database/Sinuca
# ../database/Família real
# ../database/Subsequência
# ../database/Alfabeto alienígena
# ../database/Campeonato_2018
# ../database/Plano de Internet
# ../database/Rodovia
# ../database/Figurinhas da copa
# ../database/Meteoros
# ../database/Burocracia
# ../database/Pizza da OBI
# ../database/Chefe
# ../database/Vende-se
# ../database/Plano de estacionamento
# ../database/Tarzan
# ../database/Contas a pagar
# ../database/Mapa_2017
# ../database/Maior valor
# ../database/Chuva_2019
# ../database/Calculadora
# ../database/Grupos de Trabalho
# ../database/Escadinha
# ../database/Pangrama
# ../database/Notas
# ../database/Metrô da Nlogônia
# ../database/Epidemia
# ../database/Batalha
# ../database/Jogo do Poder
# ../database/Cobertura para Celular
# ../database/Desafio do maior número
# ../database/Balé
# ../database/Atletismo
# ../database/Copa do Mundo_2014
# ../database/Pilhas de moedas
# ../database/Amigos
# ../database/Remove Dígitos
# ../database/Idade de Camila
# ../database/Trio de Bonecas
# ../database/Exploração do Capitão Levi
# ../database/Média e mediana
# ../database/Teclado
# ../database/Palavras Cruzadas
# ../database/Triângulo
# ../database/Bactérias
# ../database/Quebra-cabeças
# ../database/Cápsulas
# ../database/Mina
# ../database/Pesos
# ../database/Brigadeiros
# ../database/Cálculo
# ../database/Dengue
# ../database/Casamento de inteiros
# ../database/O Fugitivo
# ../database/Rede Social
# ../database/Capital
# ../database/Cifra da Nlogônia
# ../database/Entrevistas de emprego
# ../database/Gangorra
# ../database/Bondinho
# ../database/Postes
# ../database/Pares de números
# ../database/Língua do P
# ../database/Pirâmide_2018
# ../database/Distância entre amigos
# ../database/Times_2016
# ../database/Jogo de par ou ímpar
# ../database/Dona Minhoca_2021
# ../database/Jogo de Pratos
# ../database/Cadeado
# ../database/Baldes
# ../database/Cobra coral
# ../database/Letras
# ../database/Arquivos
# ../database/Bits
# ../database/Código
# ../database/Código_2017
# ../database/Robô_2013
# ../database/Carrinho
# ../database/Basquete de robôs
# ../database/Fast-Food
# ../database/Gincana
# ../database/Dona Minhoca
# ../database/Metrônibus
# ../database/Costa
# ../database/Escalonamento ótimo
# ../database/Arranha-céu
# ../database/Tomadas
# ../database/Bomba
# ../database/Zero para cancelar
# ../database/Troca
# ../database/Colorindo
# ../database/Corrida_2013
# ../database/Sanduíche_2016
# ../database/Matriz super-legal
# ../database/Corrida_2012
# ../database/Selos
# ../database/Banco
# ../database/Tapetes
# ../database/Guerra por território

# %%
for problem in problems:
    print(problem["title"])
# Out:
# Gomoku
# Jogo da Vida
# Muro
# Lâmpadas do hotel
# Chinelos
# Hotel
# Jogo dos copos
# Carnaval
# Tiro ao Alvo
# Transportes
# Álbum da copa
# Jogo de Dominós
# Arco e flecha
# Quadrado Mágico
# Quase primo
# Lâmpadas
# Caça ao Tesouro
# Rodovia
# Coleção de Upas
# Cinema
# Fila
# Montanha
# Chuva
# Festa olímpica
# Pô, que mão
# Relógio
# Torre
# Mesa redonda
# Sorvete
# Expressões
# Mancha
# Direção
# Nova avenida
# Telescópio
# Game Show
# Manchas de pele
# Temperatura Lunar
# Castelos da Nlogônia
# Matriz Escada
# Pedágio
# Fusões
# Capitais
# Falta uma
# Sanduíche
# Blefe
# Tabela do campeonato
# Clube dos Cinco
# Piso da escola
# Caravana
# Ônibus
# Chocolate
# Chocolate em barra
# Altas Aventuras
# Jogo dos Pinos
# Fechadura
# Sr. Toupeira
# Sr. Sapo
# Fita Colorida
# Ponto do meio
# Ogro
# Pirâmide
# Game-10
# Restaurante de pizza
# Zip
# Consecutivos
# Dança de Formatura
# Estrada
# Duplas de tênis
# Show
# Loteria
# Cubo Preto
# Robô
# Etiquetas
# Campeonato
# Dominó
# Reduzindo detalhes em um mapa
# Caminho das Pontes
# Botas Trocadas
# VAR
# Dona Lesma
# Frequencia na aula
# Salada de Frutas
# Ciclovias
# Pulo do Gato
# Semente
# Vice-campeão
# Tanque de combustível
# Candidatas
# Toca do Saci
# Dígitos
# Caminhos do reino
# Cartas
# Flíper
# Drone de Entrega
# Aeroporto
# Leilão
# Busca na Internet
# Mapa
# Medalhas
# Construtora
# Jogo
# Maximin
# Carro elétrico
# Dario e Xerxes
# Retas
# Viagem
# Soma
# Estoque
# Recibo de Compra
# Chaves
# Caverna de Ordinskaya
# Barcos da Nlogônia
# Frete
# Teste de redação
# Tacos de bilhar
# Bolas
# Prêmio
# Falha de segurança
# Bombom
# Câmara de Compensação
# Tira-teima
# Taxa
# Atlanta
# Fuga com helicóptero
# Pirâmide
# Dominó Nlogônico
# Atletismo
# Wifi
# Fila
# Ilhas
# Grand Prix da Nlogônia
# Retângulo
# Passa Bolinha
# Frequência
# Lençol
# Subcadeias
# Quadrado
# Calculando
# Ogro
# Sequência
# Xadrez
# Oficina Mecânica
# Cinco
# Quebra-cabeça
# Trem da mina
# Dominó
# Troféu
# Decifra
# Calçada Imperial
# Tesouro
# Relógios
# Cabo de guerra
# Toupeira
# Tradutor alienígena
# Copa
# Corredor
# Quadrado
# Código de Compressão
# Linhas de Ônibus
# Concurso
# Câmeras
# Passatempo
# Nota esquecida
# Torre de Dados
# Sequência Secreta
# Elevador
# Cortando o Papel
# Prefixo
# Intervalo Distinto
# Parcelamento sem juros
# Torneio de tênis
# Colchão
# Gincana
# Teleférico
# Catálogo de Músicas
# Jogo de Tabuleiro
# Fuga
# Cubo e quadrado
# Visita entre cidades
# Jardim de infância
# Prêmio do Milhão
# Móbile
# Detetive
# Concatena Dígitos
# Jogo do Preto e Branco
# Musical
# Supermercado
# PacMan
# Fotografia
# Baralho
# Floresta
# Aplicativo de Calorias
# A idade de Dona Mônica
# Receita de Bolo
# Dona Formiga
# Quadrado Mágico
# Trio de Palitinhos
# Chuva
# Setas
# Hotel Nlogônia
# Jogo da Memória
# Caminho
# Placas de Carro
# Tempo de resposta
# Avenida
# Dobradura
# Sinuca
# Família real
# Subsequência
# Alfabeto alienígena
# Campeonato
# Plano de Internet
# Rodovia
# Figurinhas da copa
# Meteoros
# Burocracia
# Pizza da OBI
# Chefe
# Vende-se
# Plano de estacionamento
# Tarzan
# Contas a pagar
# Mapa
# Maior valor
# Chuva
# Calculadora
# Grupos de Trabalho
# Escadinha
# Pangrama
# Notas
# Metrô da Nlogônia
# Epidemia
# Batalha
# Jogo do Poder
# Cobertura para Celular
# Desafio do maior número
# Balé
# Atletismo
# Copa do Mundo
# Pilhas de moedas
# Amigos
# Remove Dígitos
# Idade de Camila
# Trio de Bonecas
# Exploração do Capitão Levi
# Média e mediana
# Teclado
# Palavras Cruzadas
# Triângulo
# Bactérias
# Quebra-cabeças
# Cápsulas
# Mina
# Pesos
# Brigadeiros
# Cálculo
# Dengue
# Casamento de inteiros
# O Fugitivo
# Rede Social
# Capital
# Cifra da Nlogônia
# Entrevistas de emprego
# Gangorra
# Bondinho
# Postes
# Pares de números
# Língua do P
# Pirâmide
# Distância entre amigos
# Times
# Jogo de par ou ímpar
# Dona Minhoca
# Jogo de Pratos
# Cadeado
# Baldes
# Cobra coral
# Letras
# Arquivos
# Bits
# Código
# Código
# Robô
# Carrinho
# Basquete de robôs
# Fast-Food
# Gincana
# Dona Minhoca
# Metrônibus
# Costa
# Escalonamento ótimo
# Arranha-céu
# Tomadas
# Bomba
# Zero para cancelar
# Troca
# Colorindo
# Corrida
# Sanduíche
# Matriz super-legal
# Corrida
# Selos
# Banco
# Tapetes
# Guerra por território

# %%
df_problems = pd.DataFrame(problems)
counts_difficulty = {}

for d in df_problems["difficulty"].unique():
    cases = df_problems[df_problems["difficulty"] == d]
    counts_difficulty[d] = len(cases)
    
print(counts_difficulty)
# Out:
# {'Médio': 118, 'Fácil': 126, 'Difícil': 61}

# %%
X = ["Fácil", "Médio", "Difícil"]
y = [counts_difficulty[x] for x in X]

print(y)
print(X)
plt.figure(figsize=(8, 6))

bar_plot = plt.bar(X, y, color=['green', 'yellow', 'blue'], edgecolor='black')

plt.bar_label(bar_plot, padding=3)

plt.title("Classificação das questões pelo modelo gemini-2.5-pro")
plt.ylabel('Quantidade de Problemas')
plt.show()
# Out:
# [126, 118, 61]
# ['Fácil', 'Médio', 'Difícil']

# %%
questions_by_years = {}

i = 0
for year in df_problems["year"]:
    if questions_by_years.get(year) is None:
        questions_by_years[year] = []
    
    questions_by_years[year].append(i)
    i += 1
        
for key, count in questions_by_years.items():
    print(f"{key}: {len(count)} quantidades")

names_2015 = []

for index in questions_by_years["2015"]:
    names_2015.append(df_problems.iloc[index]["title"])

print(names_2015)
# Out:
# 2017: 24 quantidades
# 2023: 28 quantidades
# 2018: 28 quantidades
# 2016: 23 quantidades
# 2022: 24 quantidades
# 2019: 25 quantidades
# 2012: 17 quantidades
# 2013: 9 quantidades
# 2002: 5 quantidades
# 2014: 23 quantidades
# 2021: 23 quantidades
# 2015: 15 quantidades
# 2001: 5 quantidades
# 2011: 9 quantidades
# 2010: 5 quantidades
# 2024: 25 quantidades
# 2020: 15 quantidades
# 2009: 2 quantidades
# ['Torre', 'Capitais', 'Chocolate em barra', 'Fita Colorida', 'Fila', 'Quebra-cabeça', 'Prêmio do Milhão', 'Móbile', 'Família real', 'Mina', 'Cálculo', 'Cobra coral', 'Letras', 'Arquivos', 'Código']

# %% [markdown]
# ### ZERO-SHOT vs FEW-SHOT
# ---

# %%
files_path = Path("../output/results/")
dataset = {}
configs = ['_python_few', '_python_zero', '_cpp_few', '_cpp_zero']

for config in configs:
    for path in files_path.rglob('*'):
        if not path.is_file():
            continue

        parts = str(path).split("results_")
        if len(parts) < 2:
            continue

        model = parts[1]
        #print(model)
        data = pd.read_csv(path)

        df_name_2015 = pd.DataFrame()

        for i, name in enumerate(data["question_name"]):
            if name.split("_2015")[0] in names_2015:
                df_name_2015 = pd.concat([df_name_2015, data.iloc[[i]]])

        if not df_name_2015.empty:
            dataset[model] = df_name_2015

count = 0
for data in dataset["gpt_5_4_2026_03_05_python_few.csv"]["total_test_cases"]:
    count += data

print(f"Total de casos de teste: {count}")
# Out:
# Total de casos de teste: 511

# %%
rows = []
for model, data in dataset.items():
    rows.append({
        "Modelo": model,
        "AC":  data["AC"].sum()  / count,
        "WA":  data["WA"].sum()  / count,
        "RE":  data["RE"].sum()  / count,
        "TLE": data["TLE"].sum() / count,
        "CE":  data["CE"].sum()  / count,
    })

df_results = pd.DataFrame(rows)

display(
    df_results.style
    .format({
        "AC":  "{:.2%}",
        "WA":  "{:.2%}",
        "RE":  "{:.2%}",
        "TLE": "{:.2%}",
        "CE":  "{:.2%}",
    })
)
# Out:
# <style type="text/css">
# </style>
# <table id="T_6fd2d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6fd2d_level0_col0" class="col_heading level0 col0" >Modelo</th>
#       <th id="T_6fd2d_level0_col1" class="col_heading level0 col1" >AC</th>
#       <th id="T_6fd2d_level0_col2" class="col_heading level0 col2" >WA</th>
#       <th id="T_6fd2d_level0_col3" class="col_heading level0 col3" >RE</th>
#       <th id="T_6fd2d_level0_col4" class="col_heading level0 col4" >TLE</th>
#       <th id="T_6fd2d_level0_col5" class="col_heading level0 col5" >CE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6fd2d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6fd2d_row0_col0" class="data row0 col0" >mistralai_mistral_small_2603_python_few.csv</td>
#       <td id="T_6fd2d_row0_col1" class="data row0 col1" >58.51%</td>
#       <td id="T_6fd2d_row0_col2" class="data row0 col2" >38.55%</td>
#       <td id="T_6fd2d_row0_col3" class="data row0 col3" >0.00%</td>
#       <td id="T_6fd2d_row0_col4" class="data row0 col4" >2.94%</td>
#       <td id="T_6fd2d_row0_col5" class="data row0 col5" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_6fd2d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6fd2d_row1_col0" class="data row1 col0" >stepfun_step_3_5_flash_free_cpp_few.csv</td>
#       <td id="T_6fd2d_row1_col1" class="data row1 col1" >84.93%</td>
#       <td id="T_6fd2d_row1_col2" class="data row1 col2" >0.00%</td>
#       <td id="T_6fd2d_row1_col3" class="data row1 col3" >0.00%</td>
#       <td id="T_6fd2d_row1_col4" class="data row1 col4" >0.00%</td>
#       <td id="T_6fd2d_row1_col5" class="data row1 col5" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_6fd2d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6fd2d_row2_col0" class="data row2 col0" >gpt_5_4_2026_03_05_python_few.csv</td>
#       <td id="T_6fd2d_row2_col1" class="data row2 col1" >77.89%</td>
#       <td id="T_6fd2d_row2_col2" class="data row2 col2" >17.42%</td>
#       <td id="T_6fd2d_row2_col3" class="data row2 col3" >0.00%</td>
#       <td id="T_6fd2d_row2_col4" class="data row2 col4" >4.70%</td>
#       <td id="T_6fd2d_row2_col5" class="data row2 col5" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_6fd2d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6fd2d_row3_col0" class="data row3 col0" >deepseek_deepseek_v3_2_cpp_few.csv</td>
#       <td id="T_6fd2d_row3_col1" class="data row3 col1" >71.62%</td>
#       <td id="T_6fd2d_row3_col2" class="data row3 col2" >14.68%</td>
#       <td id="T_6fd2d_row3_col3" class="data row3 col3" >2.35%</td>
#       <td id="T_6fd2d_row3_col4" class="data row3 col4" >2.74%</td>
#       <td id="T_6fd2d_row3_col5" class="data row3 col5" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_6fd2d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6fd2d_row4_col0" class="data row4 col0" >deepseek_deepseek_v3_2_cpp_zero.csv</td>
#       <td id="T_6fd2d_row4_col1" class="data row4 col1" >69.86%</td>
#       <td id="T_6fd2d_row4_col2" class="data row4 col2" >15.66%</td>
#       <td id="T_6fd2d_row4_col3" class="data row4 col3" >0.00%</td>
#       <td id="T_6fd2d_row4_col4" class="data row4 col4" >5.87%</td>
#       <td id="T_6fd2d_row4_col5" class="data row4 col5" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_6fd2d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_6fd2d_row5_col0" class="data row5 col0" >anthropic_claude_sonnet_4_6_python_few.csv</td>
#       <td id="T_6fd2d_row5_col1" class="data row5 col1" >74.36%</td>
#       <td id="T_6fd2d_row5_col2" class="data row5 col2" >19.77%</td>
#       <td id="T_6fd2d_row5_col3" class="data row5 col3" >5.87%</td>
#       <td id="T_6fd2d_row5_col4" class="data row5 col4" >0.00%</td>
#       <td id="T_6fd2d_row5_col5" class="data row5 col5" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_6fd2d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_6fd2d_row6_col0" class="data row6 col0" >x_ai_grok_code_fast_1_python_zero.csv</td>
#       <td id="T_6fd2d_row6_col1" class="data row6 col1" >83.37%</td>
#       <td id="T_6fd2d_row6_col2" class="data row6 col2" >4.70%</td>
#       <td id="T_6fd2d_row6_col3" class="data row6 col3" >0.00%</td>
#       <td id="T_6fd2d_row6_col4" class="data row6 col4" >3.33%</td>
#       <td id="T_6fd2d_row6_col5" class="data row6 col5" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_6fd2d_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_6fd2d_row7_col0" class="data row7 col0" >z_ai_glm_5_python_few.csv</td>
#       <td id="T_6fd2d_row7_col1" class="data row7 col1" >95.30%</td>
#       <td id="T_6fd2d_row7_col2" class="data row7 col2" >2.15%</td>
#       <td id="T_6fd2d_row7_col3" class="data row7 col3" >0.00%</td>
#       <td id="T_6fd2d_row7_col4" class="data row7 col4" >2.54%</td>
#       <td id="T_6fd2d_row7_col5" class="data row7 col5" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_6fd2d_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_6fd2d_row8_col0" class="data row8 col0" >mistralai_mistral_small_2603_cpp_zero.csv</td>
#       <td id="T_6fd2d_row8_col1" class="data row8 col1" >52.25%</td>
#       <td id="T_6fd2d_row8_col2" class="data row8 col2" >26.61%</td>
#       <td id="T_6fd2d_row8_col3" class="data row8 col3" >0.00%</td>
#       <td id="T_6fd2d_row8_col4" class="data row8 col4" >5.09%</td>
#       <td id="T_6fd2d_row8_col5" class="data row8 col5" >7.44%</td>
#     </tr>
#     <tr>
#       <th id="T_6fd2d_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_6fd2d_row9_col0" class="data row9 col0" >z_ai_glm_5_python_zero.csv</td>
#       <td id="T_6fd2d_row9_col1" class="data row9 col1" >80.63%</td>
#       <td id="T_6fd2d_row9_col2" class="data row9 col2" >2.15%</td>
#       <td id="T_6fd2d_row9_col3" class="data row9 col3" >3.91%</td>
#       <td id="T_6fd2d_row9_col4" class="data row9 col4" >4.70%</td>
#       <td id="T_6fd2d_row9_col5" class="data row9 col5" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_6fd2d_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_6fd2d_row10_col0" class="data row10 col0" >stepfun_step_3_5_flash_free_cpp_zero.csv</td>
#       <td id="T_6fd2d_row10_col1" class="data row10 col1" >91.19%</td>
#       <td id="T_6fd2d_row10_col2" class="data row10 col2" >0.00%</td>
#       <td id="T_6fd2d_row10_col3" class="data row10 col3" >0.00%</td>
#       <td id="T_6fd2d_row10_col4" class="data row10 col4" >0.20%</td>
#       <td id="T_6fd2d_row10_col5" class="data row10 col5" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_6fd2d_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_6fd2d_row11_col0" class="data row11 col0" >deepseek_deepseek_v3_2_python_few.csv</td>
#       <td id="T_6fd2d_row11_col1" class="data row11 col1" >80.82%</td>
#       <td id="T_6fd2d_row11_col2" class="data row11 col2" >12.72%</td>
#       <td id="T_6fd2d_row11_col3" class="data row11 col3" >0.78%</td>
#       <td id="T_6fd2d_row11_col4" class="data row11 col4" >5.68%</td>
#       <td id="T_6fd2d_row11_col5" class="data row11 col5" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_6fd2d_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_6fd2d_row12_col0" class="data row12 col0" >x_ai_grok_code_fast_1_python_few.csv</td>
#       <td id="T_6fd2d_row12_col1" class="data row12 col1" >75.93%</td>
#       <td id="T_6fd2d_row12_col2" class="data row12 col2" >7.05%</td>
#       <td id="T_6fd2d_row12_col3" class="data row12 col3" >0.00%</td>
#       <td id="T_6fd2d_row12_col4" class="data row12 col4" >4.50%</td>
#       <td id="T_6fd2d_row12_col5" class="data row12 col5" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_6fd2d_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_6fd2d_row13_col0" class="data row13 col0" >z_ai_glm_5_cpp_zero.csv</td>
#       <td id="T_6fd2d_row13_col1" class="data row13 col1" >85.13%</td>
#       <td id="T_6fd2d_row13_col2" class="data row13 col2" >0.59%</td>
#       <td id="T_6fd2d_row13_col3" class="data row13 col3" >0.00%</td>
#       <td i

# %%
def parse_model_name(filename):
    name = filename.replace(".csv", "")
    
    lang = "C++" if "_cpp_" in name else "Python"
    shot = "Few-Shot" if "_few" in name else "Zero-Shot"
    
    # Remove sufixos de config
    model = re.sub(r"_(python|cpp)_(few|zero)$", "", name)
    
    return model, lang, shot

rows = []
for model_file, data in dataset.items():
    model, lang, shot = parse_model_name(model_file)
    rows.append({
        "Modelo": model.replace("_", " "),
        "Linguagem": lang,
        "Prompt": shot,
        "AC":  data["AC"].sum()  / count,
        "WA":  data["WA"].sum()  / count,
        "RE":  data["RE"].sum()  / count,
        "TLE": data["TLE"].sum() / count,
        "CE":  data["CE"].sum()  / count,
    })

df_results = pd.DataFrame(rows)

# %%
pivot = df_results.pivot_table(
    index="Modelo",
    columns=["Linguagem", "Prompt"],
    values="AC"
).round(4)

display(
    pivot.style
    .format("{:.2%}")
)
# Out:
# <style type="text/css">
# </style>
# <table id="T_79fce">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Linguagem</th>
#       <th id="T_79fce_level0_col0" class="col_heading level0 col0" colspan="2">C++</th>
#       <th id="T_79fce_level0_col2" class="col_heading level0 col2" colspan="2">Python</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Prompt</th>
#       <th id="T_79fce_level1_col0" class="col_heading level1 col0" >Few-Shot</th>
#       <th id="T_79fce_level1_col1" class="col_heading level1 col1" >Zero-Shot</th>
#       <th id="T_79fce_level1_col2" class="col_heading level1 col2" >Few-Shot</th>
#       <th id="T_79fce_level1_col3" class="col_heading level1 col3" >Zero-Shot</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Modelo</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_79fce_level0_row0" class="row_heading level0 row0" >anthropic claude sonnet 4 6</th>
#       <td id="T_79fce_row0_col0" class="data row0 col0" >71.82%</td>
#       <td id="T_79fce_row0_col1" class="data row0 col1" >59.88%</td>
#       <td id="T_79fce_row0_col2" class="data row0 col2" >74.36%</td>
#       <td id="T_79fce_row0_col3" class="data row0 col3" >57.53%</td>
#     </tr>
#     <tr>
#       <th id="T_79fce_level0_row1" class="row_heading level0 row1" >deepseek deepseek v3 2</th>
#       <td id="T_79fce_row1_col0" class="data row1 col0" >71.62%</td>
#       <td id="T_79fce_row1_col1" class="data row1 col1" >69.86%</td>
#       <td id="T_79fce_row1_col2" class="data row1 col2" >80.82%</td>
#       <td id="T_79fce_row1_col3" class="data row1 col3" >76.71%</td>
#     </tr>
#     <tr>
#       <th id="T_79fce_level0_row2" class="row_heading level0 row2" >gemini 3 1 pro preview</th>
#       <td id="T_79fce_row2_col0" class="data row2 col0" >85.32%</td>
#       <td id="T_79fce_row2_col1" class="data row2 col1" >91.39%</td>
#       <td id="T_79fce_row2_col2" class="data row2 col2" >100.00%</td>
#       <td id="T_79fce_row2_col3" class="data row2 col3" >90.22%</td>
#     </tr>
#     <tr>
#       <th id="T_79fce_level0_row3" class="row_heading level0 row3" >gpt 5 4 2026 03 05</th>
#       <td id="T_79fce_row3_col0" class="data row3 col0" >78.28%</td>
#       <td id="T_79fce_row3_col1" class="data row3 col1" >69.67%</td>
#       <td id="T_79fce_row3_col2" class="data row3 col2" >77.89%</td>
#       <td id="T_79fce_row3_col3" class="data row3 col3" >77.50%</td>
#     </tr>
#     <tr>
#       <th id="T_79fce_level0_row4" class="row_heading level0 row4" >mistralai mistral small 2603</th>
#       <td id="T_79fce_row4_col0" class="data row4 col0" >41.10%</td>
#       <td id="T_79fce_row4_col1" class="data row4 col1" >52.25%</td>
#       <td id="T_79fce_row4_col2" class="data row4 col2" >58.51%</td>
#       <td id="T_79fce_row4_col3" class="data row4 col3" >53.82%</td>
#     </tr>
#     <tr>
#       <th id="T_79fce_level0_row5" class="row_heading level0 row5" >stepfun step 3 5 flash free</th>
#       <td id="T_79fce_row5_col0" class="data row5 col0" >84.93%</td>
#       <td id="T_79fce_row5_col1" class="data row5 col1" >91.19%</td>
#       <td id="T_79fce_row5_col2" class="data row5 col2" >97.26%</td>
#       <td id="T_79fce_row5_col3" class="data row5 col3" >88.85%</td>
#     </tr>
#     <tr>
#       <th id="T_79fce_level0_row6" class="row_heading level0 row6" >x ai grok code fast 1</th>
#       <td id="T_79fce_row6_col0" class="data row6 col0" >74.56%</td>
#       <td id="T_79fce_row6_col1" class="data row6 col1" >72.02%</td>
#       <td id="T_79fce_row6_col2" class="data row6 col2" >75.93%</td>
#       <td id="T_79fce_row6_col3" class="data row6 col3" >83.37%</td>
#     </tr>
#     <tr>
#       <th id="T_79fce_level0_row7" class="row_heading level0 row7" >z ai glm 5</th>
#       <td id="T_79fce_row7_col0" class="data row7 col0" >84.54%</td>
#       <td id="T_79fce_row7_col1" class="data row7 col1" >85.13%</td>
#       <td id="T_79fce_row7_col2" class="data row7 col2" >95.30%</td>
#       <td id="T_79fce_row7_col3" class="data row7 col3" >80.63%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Top 5 modelos pela média de AC entre todas as configs
top5_models = (
    df_results.groupby("Modelo")["AC"]
    .mean()
    .sort_values(ascending=False)
    .head(5)
    .index
)

df_top5 = df_results[df_results["Modelo"].isin(top5_models)]

fig, ax = plt.subplots(figsize=(12, 6))  # menor pois são só 5 modelos

configs = df_top5[["Linguagem", "Prompt"]].drop_duplicates()
models = top5_models
y = np.arange(len(models))
height = 0.2

for i, (_, cfg) in enumerate(configs.iterrows()):
    subset = df_top5[
        (df_top5["Linguagem"] == cfg.Linguagem) &
        (df_top5["Prompt"] == cfg.Prompt)
    ].set_index("Modelo")["AC"].reindex(models).fillna(0)

    bars = ax.barh(y + i * height, subset * 100, height, label=f"{cfg.Linguagem} / {cfg.Prompt}")

    for bar, val in zip(bars, subset * 100):
        if val > 0:
            ax.text(
                bar.get_width() + 0.5,
                bar.get_y() + bar.get_height() / 2,
                f"{val:.0f}%",
                ha="left", va="center", fontsize=8
            )

ax.set_yticks(y + height * 1.5)
ax.set_yticklabels(models, fontsize=10)
ax.set_xlabel("AC (%)")
ax.set_title("Top 5 Modelos: Taxa de Acerto (AC) por Configuração — OBI 2015 (511 casos de teste)")
ax.legend(title="Config")
ax.set_xlim(0, 120)
ax.grid(False)

plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12, 10))

configs = df_results[["Linguagem", "Prompt"]].drop_duplicates()
models = df_results["Modelo"].unique()


y_indices = np.arange(len(models))
bar_height = 0.2
offset = 0 

for i, (_, cfg) in enumerate(configs.iterrows()):
    subset = df_results[
        (df_results["Linguagem"] == cfg.Linguagem) & 
        (df_results["Prompt"] == cfg.Prompt)
    ].set_index("Modelo")["AC"].reindex(models).fillna(0)
    
    current_y = y_indices + (i * bar_height)
    label_text = f"{cfg.Linguagem} / {cfg.Prompt}"
    
    bars = ax.barh(current_y, subset * 100, bar_height, label=label_text)
    
    for bar in bars:
        width = bar.get_width()
        if width > 0:
            ax.text(
                width + 0.5,
                bar.get_y() + bar.get_height() / 2,
                f"{width:.0f}%", 
                ha="left", 
                va="center", 
                fontsize=8
            )

ax.set_yticks(y_indices + (len(configs) * bar_height) / 2 - (bar_height / 2))
ax.set_yticklabels(models, fontsize=10)
ax.set_xlabel("Taxa de Acerto (%)", fontweight='bold')
ax.set_title("Benchmarking OBI 2015: Taxa de Acerto (AC) por Modelo e Configuração", fontsize=14, pad=20)
ax.set_xlim(0, 110)
ax.legend(title="Configurações (Linguagem / Prompt)", bbox_to_anchor=(1.05, 1), loc='upper left')

plt.grid(axis='x', linestyle='--', alpha=0.4)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Estatísticas do Judge
#
# ---

# %%
def average(data):
    n = len(data)
    count = 0
    
    for value in data:
        count += value
        
    return float(count/n)

# %%
def per_ac_questions(data):
    n = len(data)
    count = 0
    for value in data["judge_predict"]:
        if value == "AC":
            count += 1
            
    return float(count/n)

# %%
files_path = Path("../output/results/")

dataset = {}

for path in list(files_path.rglob('*')):        
    model = str(path).split("results_")[1]
    if not "_python_few" in model:
        continue
    
    model = model.split("_python_few")[0]
    
    dataset[model] = pd.read_csv(path)

# %%
metrics = {}

for key, data in dataset.items():
    
    row = {}
    
    hard_questions = data[data["difficulty"] == "Difícil"]
    row['hard_ac'] = per_ac_questions(hard_questions)
    
    medium_questions = data[data["difficulty"] == "Médio"]
    row['medium_ac'] = per_ac_questions(medium_questions)
    
    easy_questions = data[data["difficulty"] == "Fácil"]
    row['easy_ac'] = per_ac_questions(easy_questions)
    
    row['avg_tokens'] = average(data["total_tokens"])
    row['avg_cost'] = average(data["cost_prompt"])
    row['avg_create_code'] = average(data["llm_code_creation_time"])
    
    metrics[key] = row

# %%
rows = []
names_model = {
    "anthropic_claude_sonnet_4_6": "Sonnet 4.6",
    "gpt_5_4_2026_03_05": "GPT 5.4",
    "z_ai_glm_5": "GLM 5",
    "deepseek_deepseek_v3_2": "DeepSeek V3.2",
    "x_ai_grok_code_fast_1": "Grok Code Fast 1",
    "stepfun_step_3_5_flash_free": "Step 3.5 Flash Free",
    "gemini_3_1_pro_preview": "Gemini 3.1 Pro",
    "mistralai_mistral_small_2603": "Mistral Small 4"
}

for key, data in metrics.items():
    rows.append({
        "Modelo":               names_model[key],
        "Fácil AC (%)":         data["easy_ac"] * 100,
        "Média AC (%)":         data["medium_ac"] * 100,
        "Difícil AC (%)":       data["hard_ac"] * 100,
        "Tokens (Média)":       data["avg_tokens"],
        "Custo Médio (US$)":    data["avg_cost"],
        "Tempo Médio (s)":      data["avg_create_code"], 
    })

df = pd.DataFrame(rows).sort_values("Modelo").reset_index(drop=True)

display(
    df.style
    .format({
        "Fácil AC (%)":       "{:.2f}",
        "Média AC (%)":       "{:.2f}",
        "Difícil AC (%)":     "{:.2f}",
        "Tokens (Média)":     "{:.0f}",
        "Custo Médio (US$)":  "{:.4f}",
        "Tempo Médio (s)":    "{:.0f}",
    })
    .set_properties(**{'text-align': 'center'})
    .set_table_styles([dict(selector='th', props=[('text-align', 'center')])])
    .hide(axis="index")
)
# Out:
# <style type="text/css">
# #T_d95fd th {
#   text-align: center;
# }
# #T_d95fd_row0_col0, #T_d95fd_row0_col1, #T_d95fd_row0_col2, #T_d95fd_row0_col3, #T_d95fd_row0_col4, #T_d95fd_row0_col5, #T_d95fd_row0_col6, #T_d95fd_row1_col0, #T_d95fd_row1_col1, #T_d95fd_row1_col2, #T_d95fd_row1_col3, #T_d95fd_row1_col4, #T_d95fd_row1_col5, #T_d95fd_row1_col6, #T_d95fd_row2_col0, #T_d95fd_row2_col1, #T_d95fd_row2_col2, #T_d95fd_row2_col3, #T_d95fd_row2_col4, #T_d95fd_row2_col5, #T_d95fd_row2_col6, #T_d95fd_row3_col0, #T_d95fd_row3_col1, #T_d95fd_row3_col2, #T_d95fd_row3_col3, #T_d95fd_row3_col4, #T_d95fd_row3_col5, #T_d95fd_row3_col6, #T_d95fd_row4_col0, #T_d95fd_row4_col1, #T_d95fd_row4_col2, #T_d95fd_row4_col3, #T_d95fd_row4_col4, #T_d95fd_row4_col5, #T_d95fd_row4_col6, #T_d95fd_row5_col0, #T_d95fd_row5_col1, #T_d95fd_row5_col2, #T_d95fd_row5_col3, #T_d95fd_row5_col4, #T_d95fd_row5_col5, #T_d95fd_row5_col6, #T_d95fd_row6_col0, #T_d95fd_row6_col1, #T_d95fd_row6_col2, #T_d95fd_row6_col3, #T_d95fd_row6_col4, #T_d95fd_row6_col5, #T_d95fd_row6_col6, #T_d95fd_row7_col0, #T_d95fd_row7_col1, #T_d95fd_row7_col2, #T_d95fd_row7_col3, #T_d95fd_row7_col4, #T_d95fd_row7_col5, #T_d95fd_row7_col6 {
#   text-align: center;
# }
# </style>
# <table id="T_d95fd">
#   <thead>
#     <tr>
#       <th id="T_d95fd_level0_col0" class="col_heading level0 col0" >Modelo</th>
#       <th id="T_d95fd_level0_col1" class="col_heading level0 col1" >Fácil AC (%)</th>
#       <th id="T_d95fd_level0_col2" class="col_heading level0 col2" >Média AC (%)</th>
#       <th id="T_d95fd_level0_col3" class="col_heading level0 col3" >Difícil AC (%)</th>
#       <th id="T_d95fd_level0_col4" class="col_heading level0 col4" >Tokens (Média)</th>
#       <th id="T_d95fd_level0_col5" class="col_heading level0 col5" >Custo Médio (US$)</th>
#       <th id="T_d95fd_level0_col6" class="col_heading level0 col6" >Tempo Médio (s)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_d95fd_row0_col0" class="data row0 col0" >DeepSeek V3.2</td>
#       <td id="T_d95fd_row0_col1" class="data row0 col1" >85.71</td>
#       <td id="T_d95fd_row0_col2" class="data row0 col2" >62.71</td>
#       <td id="T_d95fd_row0_col3" class="data row0 col3" >26.23</td>
#       <td id="T_d95fd_row0_col4" class="data row0 col4" >1785</td>
#       <td id="T_d95fd_row0_col5" class="data row0 col5" >0.0007</td>
#       <td id="T_d95fd_row0_col6" class="data row0 col6" >18</td>
#     </tr>
#     <tr>
#       <td id="T_d95fd_row1_col0" class="data row1 col0" >GLM 5</td>
#       <td id="T_d95fd_row1_col1" class="data row1 col1" >95.24</td>
#       <td id="T_d95fd_row1_col2" class="data row1 col2" >88.98</td>
#       <td id="T_d95fd_row1_col3" class="data row1 col3" >65.57</td>
#       <td id="T_d95fd_row1_col4" class="data row1 col4" >7830</td>
#       <td id="T_d95fd_row1_col5" class="data row1 col5" >0.0220</td>
#       <td id="T_d95fd_row1_col6" class="data row1 col6" >115</td>
#     </tr>
#     <tr>
#       <td id="T_d95fd_row2_col0" class="data row2 col0" >GPT 5.4</td>
#       <td id="T_d95fd_row2_col1" class="data row2 col1" >89.68</td>
#       <td id="T_d95fd_row2_col2" class="data row2 col2" >68.64</td>
#       <td id="T_d95fd_row2_col3" class="data row2 col3" >40.98</td>
#       <td id="T_d95fd_row2_col4" class="data row2 col4" >1499</td>
#       <td id="T_d95fd_row2_col5" class="data row2 col5" >0.0065</td>
#       <td id="T_d95fd_row2_col6" class="data row2 col6" >3</td>
#     </tr>
#     <tr>
#       <td id="T_d95fd_row3_col0" class="data row3 col0" >Gemini 3.1 Pro</td>
#       <td id="T_d95fd_row3_col1" class="data row3 col1" >97.62</td>
#       <td id="T_d95fd_row3_col2" class="data row3 col2" >94.92</td>
#       <td id="T_d95fd_row3_col3" class="data row3 col3" >93.44</td>
#       <td id="T_d95fd_row3_col4" class="data row3 col4" >1707</td>
#       <td id="T_d95fd_row3_col5" class="data row3 col5" >0.0061</td>
#       <td id="T_d95fd_row3_col6" class="data row3 col6" >54</td>
#     </tr>
#     <tr>
#       <td id="T_d95fd_row4_col0" class="data row4 col0" >Grok Code Fast 1</td>
#       <td id="T_d95fd_row4_col1" class="data row4 col1" >92.06</td>
#       <td id="T_d95fd_row4_col2" class="data row4 col2" >77.12</td>
#       <td id="T_d95fd_row4_col3" class="data row4 col3" >36.07</td>
#       <td id="T_d95fd_row4_col4" class="data row4 col4" >6939</td>
#       <td id="T_d95fd_row4_col5" class="data row4 col5" >0.0085</td>
#       <td id="T_d95fd_row4_col6" class="data row4 col6" >24</td>
#     </tr>
#     <tr>
#       <td id="T_d95fd_row5_col0" class="data row5 col0" >Mistral Small 4</td>
#       <td id="T_d95fd_row5_col1" class="data row5 col1" >63.49</td>
#       <td id="T_d95fd_row5_col2" class="data row5 col2" >46.61</td>
#       <td id="T_d95fd_row5_col3" class="data row5 col3" >11.48</td>
#       <td id="T_d95fd_row5_col4" class="data row5 col4" >1662</td>
#       <td id="T_d95fd_row5_col5" class="data row5 col5" >0.0004</td>
#       <td id="T_d95fd_row5_col6" class="data row5 col6" >2</td>
#     </tr>
#     <tr>
#       <td id="T_d95fd_row6_col0" class="data row6 col0" >Sonnet 4.6</td>
#       <td id="T_d95fd_row6_col1" class="data row6 col1" >88.89</td>
#       <td id="T_d95fd_row6_col2" class="data row6 col2" >83.05</td>
#       <td id="T_d95fd_row6_col3" class="data row6 col3" >45.90</td>
#       <td id="T_d95fd_row6_col4" class="data row6 col4" >2877</td>
#       <td id="T_d95fd_row6_col5" class="data row6 col5" >0.0237</td>
#       <td id="T_d95fd_row6_col6" class="data row6 col6" >18</td>
#     </tr>
#     <tr>
#       <td id="T_d95fd_row7_col0" class="data row7 col0" >Step 3.5 Flash Free</td>
#       <td id="T_d95fd_row7_col1" class="data row7 col1" >96.83</td>
#       <td id="T_d95fd_row7_col2" class="data row7 col2" >86.44</td>
#       <td id="T_d95fd_row7_col3" class="data row7 col3" >65.57</td>
#       <td id="T_d95fd_row7_col4" class="data row7 col4" >13901</td>
#       <td id="T_d95fd_row7_col5" class="data row7 col5" >0.0000</td>
#       <td id="T_d95fd_row7_col6" class="data row7 col6" >120</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Estatisticas gerais
# ---

# %%
metrics_geral = {}

# %%
metrics_geral["total de tokens"] = {}

for key, data in dataset.items():
    total_tokens_cases = 0

    for count_test in data["total_tokens"]:
        total_tokens_cases += count_test
    
    metrics_geral["total de tokens"][key] = total_tokens_cases
    
    print(f"Total de tokens [{key}]: {total_tokens_cases}")
# Out:
# Total de tokens [mistralai_mistral_small_2603]: 506877
# Total de tokens [gpt_5_4_2026_03_05]: 457127
# Total de tokens [anthropic_claude_sonnet_4_6]: 877409
# Total de tokens [z_ai_glm_5]: 2388250
# Total de tokens [deepseek_deepseek_v3_2]: 544573
# Total de tokens [x_ai_grok_code_fast_1]: 2116256
# Total de tokens [stepfun_step_3_5_flash_free]: 4239921
# Total de tokens [gemini_3_1_pro_preview]: 520516

# %%
metrics_geral["tempo de resolução"] = {}

exp_time = 0

for key, data in dataset.items():
    total_time = 0

    for time in data["llm_code_creation_time"]:
        total_time += time
    
    exp_time += total_time
    
    total_time = int(total_time)
    seg = total_time % 60
    total_time = total_time - seg
    total_time = total_time / 60 # total_time em minutos
    
    h = total_time / 60
    min = total_time % 60
    
    metrics_geral["tempo de resolução"][key] = f"{int(h)}h {int(min)} min {seg}s"
    print(f"Tem de resolução das questões pelo modelo {key}: {int(h)}h {int(min)} min {seg}s")

exp_time = int(exp_time)
seg = exp_time % 60
exp_time = exp_time - seg
exp_time = exp_time / 60 # exp_time em minutos
    
h = exp_time / 60
min = exp_time % 60

print(f"Duração total do experimento: {int(h)}h {int(min)} min {seg}s")
# Out:
# Tem de resolução das questões pelo modelo mistralai_mistral_small_2603: 0h 9 min 59s
# Tem de resolução das questões pelo modelo gpt_5_4_2026_03_05: 0h 16 min 5s
# Tem de resolução das questões pelo modelo anthropic_claude_sonnet_4_6: 1h 33 min 42s
# Tem de resolução das questões pelo modelo z_ai_glm_5: 9h 42 min 31s
# Tem de resolução das questões pelo modelo deepseek_deepseek_v3_2: 1h 32 min 26s
# Tem de resolução das questões pelo modelo x_ai_grok_code_fast_1: 1h 59 min 45s
# Tem de resolução das questões pelo modelo stepfun_step_3_5_flash_free: 10h 8 min 2s
# Tem de resolução das questões pelo modelo gemini_3_1_pro_preview: 4h 35 min 28s
# Duração total do experimento: 29h 58 min 2s

# %%
total = 0
metrics_geral["total do custo"] = {}

for key, data in dataset.items():
    total_cost = 0

    for count_test in data["cost_prompt"]:
        total_cost += count_test
    
    total += total_cost
    
    metrics_geral["total do custo"][key] = f"U$ {total_cost:.2f}"
    print(f"Total do custo [{key}]: U$ {total_cost:.2f}")
    
print(f"Valor gasto atualmente: U$ {total:.2f}")
# Out:
# Total do custo [mistralai_mistral_small_2603]: U$ 0.11
# Total do custo [gpt_5_4_2026_03_05]: U$ 1.98
# Total do custo [anthropic_claude_sonnet_4_6]: U$ 7.22
# Total do custo [z_ai_glm_5]: U$ 6.72
# Total do custo [deepseek_deepseek_v3_2]: U$ 0.21
# Total do custo [x_ai_grok_code_fast_1]: U$ 2.58
# Total do custo [stepfun_step_3_5_flash_free]: U$ 0.00
# Total do custo [gemini_3_1_pro_preview]: U$ 1.86
# Valor gasto atualmente: U$ 20.69

# %%
metrics_geral["no code"] = {}

for key, data in dataset.items():
    no_code = 0

    for judge in data["judge_predict"]:
        if judge == "NO CODE":
            no_code += 1
    
    metrics_geral["no code"][key] = no_code
    print(f"Não produziu código [{key}]: {no_code}")
# Out:
# Não produziu código [mistralai_mistral_small_2603]: 0
# Não produziu código [gpt_5_4_2026_03_05]: 0
# Não produziu código [anthropic_claude_sonnet_4_6]: 0
# Não produziu código [z_ai_glm_5]: 10
# Não produziu código [deepseek_deepseek_v3_2]: 0
# Não produziu código [x_ai_grok_code_fast_1]: 4
# Não produziu código [stepfun_step_3_5_flash_free]: 19
# Não produziu código [gemini_3_1_pro_preview]: 0

# %%
rows = []

for model_key in metrics_geral["total de tokens"].keys():
    rows.append({
        "Modelo":               names_model.get(model_key, model_key),
        "Total de Tokens":      metrics_geral["total de tokens"][model_key],
        "Tempo de Resolução":   metrics_geral["tempo de resolução"][model_key],
        "Custo Total":          metrics_geral["total do custo"][model_key],
        "Saída Sem Código":           metrics_geral["no code"][model_key],
    })

df_geral = pd.DataFrame(rows).sort_values("Modelo").reset_index(drop=True)

display(
    df_geral.style
    .format({
        "Total de Tokens": "{:,.0f}",
    })
)
# Out:
# <style type="text/css">
# </style>
# <table id="T_50837">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_50837_level0_col0" class="col_heading level0 col0" >Modelo</th>
#       <th id="T_50837_level0_col1" class="col_heading level0 col1" >Total de Tokens</th>
#       <th id="T_50837_level0_col2" class="col_heading level0 col2" >Tempo de Resolução</th>
#       <th id="T_50837_level0_col3" class="col_heading level0 col3" >Custo Total</th>
#       <th id="T_50837_level0_col4" class="col_heading level0 col4" >Saída Sem Código</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_50837_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_50837_row0_col0" class="data row0 col0" >DeepSeek V3.2</td>
#       <td id="T_50837_row0_col1" class="data row0 col1" >544,573</td>
#       <td id="T_50837_row0_col2" class="data row0 col2" >1h 32 min 26s</td>
#       <td id="T_50837_row0_col3" class="data row0 col3" >U$ 0.21</td>
#       <td id="T_50837_row0_col4" class="data row0 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_50837_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_50837_row1_col0" class="data row1 col0" >GLM 5</td>
#       <td id="T_50837_row1_col1" class="data row1 col1" >2,388,250</td>
#       <td id="T_50837_row1_col2" class="data row1 col2" >9h 42 min 31s</td>
#       <td id="T_50837_row1_col3" class="data row1 col3" >U$ 6.72</td>
#       <td id="T_50837_row1_col4" class="data row1 col4" >10</td>
#     </tr>
#     <tr>
#       <th id="T_50837_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_50837_row2_col0" class="data row2 col0" >GPT 5.4</td>
#       <td id="T_50837_row2_col1" class="data row2 col1" >457,127</td>
#       <td id="T_50837_row2_col2" class="data row2 col2" >0h 16 min 5s</td>
#       <td id="T_50837_row2_col3" class="data row2 col3" >U$ 1.98</td>
#       <td id="T_50837_row2_col4" class="data row2 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_50837_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_50837_row3_col0" class="data row3 col0" >Gemini 3.1 Pro</td>
#       <td id="T_50837_row3_col1" class="data row3 col1" >520,516</td>
#       <td id="T_50837_row3_col2" class="data row3 col2" >4h 35 min 28s</td>
#       <td id="T_50837_row3_col3" class="data row3 col3" >U$ 1.86</td>
#       <td id="T_50837_row3_col4" class="data row3 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_50837_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_50837_row4_col0" class="data row4 col0" >Grok Code Fast 1</td>
#       <td id="T_50837_row4_col1" class="data row4 col1" >2,116,256</td>
#       <td id="T_50837_row4_col2" class="data row4 col2" >1h 59 min 45s</td>
#       <td id="T_50837_row4_col3" class="data row4 col3" >U$ 2.58</td>
#       <td id="T_50837_row4_col4" class="data row4 col4" >4</td>
#     </tr>
#     <tr>
#       <th id="T_50837_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_50837_row5_col0" class="data row5 col0" >Mistral Small 4</td>
#       <td id="T_50837_row5_col1" class="data row5 col1" >506,877</td>
#       <td id="T_50837_row5_col2" class="data row5 col2" >0h 9 min 59s</td>
#       <td id="T_50837_row5_col3" class="data row5 col3" >U$ 0.11</td>
#       <td id="T_50837_row5_col4" class="data row5 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_50837_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_50837_row6_col0" class="data row6 col0" >Sonnet 4.6</td>
#       <td id="T_50837_row6_col1" class="data row6 col1" >877,409</td>
#       <td id="T_50837_row6_col2" class="data row6 col2" >1h 33 min 42s</td>
#       <td id="T_50837_row6_col3" class="data row6 col3" >U$ 7.22</td>
#       <td id="T_50837_row6_col4" class="data row6 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_50837_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_50837_row7_col0" class="data row7 col0" >Step 3.5 Flash Free</td>
#       <td id="T_50837_row7_col1" class="data row7 col1" >4,239,921</td>
#       <td id="T_50837_row7_col2" class="data row7 col2" >10h 8 min 2s</td>
#       <td id="T_50837_row7_col3" class="data row7 col3" >U$ 0.00</td>
#       <td id="T_50837_row7_col4" class="data row7 col4" >19</td>
#     </tr>
#   </tbody>
# </table>

# %%
topics = []

for problem in problems:
    if problem.get("topics") is not None:
        topics.extend(problem["topics"])


print(set(topics))

topics_grafos = ['grafos', 'ciclos em grafos', 'busca em largura', 'busca em profundidade']
topics_pd = ['programação dinâmica']

questions_by_topics = {"g": [], "pd": []}

for name, problem in zip(questions_name, problems):
    topicos = [t.lower() for t in problem.get('topics', [])]
    if any(t in topics_grafos for t in topicos):
        questions_by_topics["g"].append(name)
    elif any(t in topics_pd for t in topicos):
        questions_by_topics["pd"].append(name)

print(questions_by_topics)
print(f"grafos: {len(questions_by_topics['g'])}, programação dinâmica: {len(questions_by_topics['pd'])}")

len_g = len(questions_by_topics['g'])
len_pd = len(questions_by_topics['pd'])

len_g = len(questions_by_topics['g'])
len_pd = len(questions_by_topics['pd'])

data_by_dataset = {}
for key, data in dataset.items():
    data_by_dataset[key] = {'g': 0, 'pd': 0}
    
    df = pd.DataFrame(data)
    df = df[df["judge_predict"] == "AC"]
    
    for _, row in df.iterrows():
        if row["question_name"] in questions_by_topics['g']:
            data_by_dataset[key]['g'] += 1
        elif row["question_name"] in questions_by_topics['pd']:
            data_by_dataset[key]['pd'] += 1

print(data_by_dataset)
print(f"grafos: {len_g}, programação dinâmica: {len_pd}")
# Out:
# {'geometria', 'estruturas de dados', 'Algoritmo de Dijkstra', 'union-find', 'somas de prefixo', 'fila de prioridade', 'programação dinâmica', 'Busca Binária', 'strings', 'Busca em Profundidade (DFS)', 'construção', 'Algoritmo Guloso', 'arrays', 'Busca em Largura', 'busca em largura (bfs)', 'sliding window', 'ciclos em grafos', 'Força Bruta', 'menor ancestral comum (lca)', 'busca em profundidade (DFS)', 'hash table', 'Backtracking', 'Implementação', 'princípio da inclusão-exclusão', 'lazy propagation', 'data structures', 'matrizes', 'Greedy', 'dois ponteiros', 'Menor Ancestral Comum (LCA)', 'backtracking', 'componentes conexas', 'algoritmos gulosos', 'Árvore de Segmentos', 'Árvores', 'busca em largura', 'recursão', 'busca em largura (BFS)', 'algoritmo guloso', 'matemática', 'implementação', 'prefix sums', 'union-find (dsu)', 'busca em largura / profundidade', 'Ordenação', 'força bruta', 'Programação Dinâmica', 'ordenação topológica', 'busca em profundidade', 'pilha', 'binary lifting', 'Detecção de Ciclos', 'mathematics', 'busca binária', 'ordenação', 'euler tour', 'árvores', 'mapas / tabelas hash', 'hashing', 'ad-hoc', 'Union-Find / DSU', 'greedy', 'Árvore Geradora Mínima', 'lowest common ancestor (lca)', 'Estruturas de Dados', 'busca em profundidade (dfs)', 'simulação', 'união-busca (dsu)', 'guloso', 'busca', 'implementation', 'iniciante', 'Lógica', 'segment tree', 'componentes fortemente conexas', 'two pointers', 'caminho euleriano', 'algoritmos de caminho mínimo', 'brute force', 'grafos', 'Grafos', 'bitmask', 'Busca em Largura (BFS)', 'árvore geradora máxima', 'Simulação'}
# {'g': ['Transportes', 'Rodovia_2013', 'Coleção de Upas', 'Mancha', 'Manchas de pele', 'Castelos da Nlogônia', 'Pedágio_2002', 'Fusões', 'Capitais', 'Sanduíche', 'Ônibus', 'Sr. Toupeira', 'Sr. Sapo', 'Dominó_2001', 'Reduzindo detalhes em um mapa', 'Caminho das Pontes', 'Ciclovias', 'Pulo do Gato', 'Toca do Saci', 'Caminhos do reino', 'Aeroporto', 'Mapa', 'Carro elétrico', 'Viagem', 'Barcos da Nlogônia', 'Frete', 'Câmara de Compensação', 'Wifi', 'Ilhas', 'Grand Prix da Nlogônia', 'Passa Bolinha', 'Quebra-cabeça', 'Trem da mina', 'Tesouro', 'Relógios', 'Toupeira', 'Linhas de Ônibus', 'Câmeras', 'Fuga', 'Visita entre cidades', 'Detetive', 'Jogo do Preto e Branco', 'Dona Formiga', 'Setas', 'Jogo da Memória', 'Família real', 'Rodovia', 'Burocracia', 'Chefe', 'Tarzan', 'Mapa_2017', 'Chuva_2019', 'Metrô da Nlogônia', 'Jogo do Poder', 'Cobertura para Celular', 'Copa do Mundo_2014', 'Mina', 'Dengue', 'Entrevistas de emprego', 'Times_2016', 'Dona Minhoca_2021', 'Robô_2013', 'Carrinho', 'Gincana', 'Dona Minhoca', 'Metrônibus', 'Escalonamento ótimo', 'Bomba', 'Colorindo'], 'pd': ['Muro', 'Caça ao Tesouro_2002', 'Chuva', 'Altas Aventuras', 'Fita Colorida', 'Etiquetas', 'Recibo de Compra', 'Caverna de Ordinskaya', 'Taxa', 'Dominó Nlogônico', 'Subcadeias', 'Sequência', 'Calçada Imperial', 'Tradutor alienígena', 'Corredor', 'Torre de Dados', 'Catálogo de Músicas', 'Jogo de Tabuleiro', 'Sinuca', 'Pilhas de moedas', 'Amigos', 'Remove Dígitos', 'Trio de Bonecas', 'Quebra-cabeças', 'Brigadeiros', 'Pirâmide_2018', 'Distância entre amigos', 'Letras', 'Bits', 'Matriz super-legal']}
# grafos: 69, programação dinâmica: 30
# {'mistralai_mistral_small_2603': {'g': 22, 'pd': 8}, 'gpt_5_4_2026_03_05': {'g': 39, 'pd': 19}, 'anthropic_claude_sonnet_4_6': {'g': 47, 'pd': 20}, 'z_ai_glm_5': {'g': 51, 'pd': 24}, 'deepseek_deepseek_v3_2': {'g': 28, 'pd': 16}, 'x_ai_grok_code_fast_1': {'g': 44, 'pd': 16}, 'stepfun_step_3_5_flash_free': {'g': 46, 'pd': 23}, 'gemini_3_1_pro_preview': {'g': 63, 'pd': 28}}
# grafos: 69, programação dinâmica: 30

# %%
modelos = list(data_by_dataset.keys())
modelos_sorted = sorted(data_by_dataset.keys(), key=lambda k: data_by_dataset[k]['g'] + data_by_dataset[k]['pd'], reverse=True)
modelos = modelos_sorted
raw_g  = [data_by_dataset[k]['g']  for k in modelos]
raw_pd = [data_by_dataset[k]['pd'] for k in modelos]
g_pct  = [v / (len_g + len_pd) * 100 for v in raw_g]
pd_pct = [v / (len_g + len_pd) * 100 for v in raw_pd]

x = np.arange(len(modelos))
w = 0.55

fig, ax = plt.subplots(figsize=(13, 5))
bars_g  = ax.bar(x, g_pct,  w, label='Grafos',         color='#378ADD')
bars_pd = ax.bar(x, pd_pct, w, label='Prog. dinâmica', color='#1D9E75', bottom=g_pct)

for i in range(len(modelos)):
    # % dentro da barra de grafos
    if g_pct[i] > 3:
        ax.text(x[i], g_pct[i] / 2, f'{g_pct[i]:.1f}%',
                ha='center', va='center', fontsize=8, color='black', fontweight='bold')

    # % dentro da barra de prog. dinâmica
    if pd_pct[i] > 3:
        ax.text(x[i], g_pct[i] + pd_pct[i] / 2, f'{pd_pct[i]:.1f}%',
                ha='center', va='center', fontsize=8, color='black', fontweight='bold')

    # % total acima da barra
    total = g_pct[i] + pd_pct[i]
    ax.text(x[i], total + 1, f'{total:.1f}%',
            ha='center', va='bottom', fontsize=8, color='gray')

ax.set_xticks(x)
ax.set_xticklabels(modelos, rotation=30, ha='right', fontsize=9)
ax.set_ylabel('% de acertos')
ax.set_ylim(0, 100)
ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda v, _: f'{v:.0f}%'))
ax.legend()
ax.grid(axis='y', alpha=0.2)
ax.spines[['top', 'right']].set_visible(False)
plt.tight_layout()
plt.show()
