# %% [markdown]
# # Métricas do sistemas
# ---

# %% [markdown]
# ### Bibliotecas
#
# ---
#
# Caso não consiga instalar execute `pip install -r requirements.txt` no terminal

# %%
# !uv pip install -r ../requirements.txt
# Out:
# Using Python 3.10.11 environment at: C:\Users\Victo\Desktop\Ufal\obi-benchmarking\.venv
# Checked 10 packages in 3.69s

# %%
from pathlib import Path
import matplotlib.pyplot as plt
import pandas as pd
import json
import numpy as np
import re
from IPython.display import display

# %%
path_database = Path("../database")
questions_path = []
        
for folder in list(path_database.iterdir()):
    print(folder)
    if folder.is_dir():
        questions_path.append(folder)
        
problems = []
questions_name = []
for question_path in questions_path:
    questions_name.append(question_path.name)
    problems.append(json.loads(Path(question_path / "problem.json").read_text(encoding="utf-8")))
# Out:
# ..\database\A idade de Dona Mônica
# ..\database\Acelerador de Partículas
# ..\database\Aeroporto
# ..\database\Alfabeto Alienígena
# ..\database\Altas Aventuras
# ..\database\Amigos
# ..\database\Aplicativo de Calorias
# ..\database\Arara!
# ..\database\Arco e flecha
# ..\database\Arquivos
# ..\database\Arranha-céu
# ..\database\Atlanta
# ..\database\Atletismo
# ..\database\Auto Estrada
# ..\database\Autorama
# ..\database\Avenida
# ..\database\Avião
# ..\database\Aviões de papel
# ..\database\Ações da Bolsa
# ..\database\Bactérias
# ..\database\Bafo
# ..\database\Baldes
# ..\database\Balé
# ..\database\Banco
# ..\database\Banda
# ..\database\Baralho
# ..\database\Barcos da Nlogônia
# ..\database\Basquete de robôs
# ..\database\Batalha
# ..\database\Batalha Naval
# ..\database\Bingo!
# ..\database\Bits
# ..\database\Bits Trocados
# ..\database\Blefe
# ..\database\Bolas
# ..\database\Bomba
# ..\database\Bombom
# ..\database\Bondinho
# ..\database\Botas Trocadas
# ..\database\Brigadeiros
# ..\database\Burocracia
# ..\database\Busca na Internet
# ..\database\Cabo de guerra
# ..\database\Cachecol da Vovó Vitória
# ..\database\Cadeado
# ..\database\Cadeiras do auditório
# ..\database\Cafeteria
# ..\database\Café com Leite
# ..\database\Caixeiro Viajante
# ..\database\Caixinha de palitos
# ..\database\Calculadora
# ..\database\Calculando
# ..\database\Calçada Imperial
# ..\database\Caminho
# ..\database\Caminho das Pontes
# ..\database\Caminhos do reino
# ..\database\Camisetas da Olimpíada
# ..\database\Campeonato
# ..\database\Campeonato_2018
# ..\database\Campo de Minhocas
# ..\database\Campo Minado
# ..\database\Candidatas
# ..\database\Capitais
# ..\database\Capital
# ..\database\Caravana
# ..\database\Carga Pesada
# ..\database\Carnaval
# ..\database\Carrinho
# ..\database\Carro elétrico
# ..\database\Cartas
# ..\database\Casamento de inteiros
# ..\database\Castelos da Nlogônia
# ..\database\Catálogo de Músicas
# ..\database\Cavalos
# ..\database\Caverna de Ordinskaya
# ..\database\Caça ao Tesouro
# ..\database\Caça ao Tesouro_2011
# ..\database\Caçadores de Mitos
# ..\database\Chaves
# ..\database\Chinelos
# ..\database\Chocolate
# ..\database\Chocolate em barra
# ..\database\Chocolate_2012
# ..\database\Chuva
# ..\database\Chuva_2011
# ..\database\Chuva_2016
# ..\database\Chuva_2019
# ..\database\Chuva_2022
# ..\database\Ciclovias
# ..\database\Cifra da Nlogônia
# ..\database\Cinco
# ..\database\Cinema
# ..\database\Clube dos Cinco
# ..\database\Cobertura para Celular
# ..\database\Cobra coral
# ..\database\Cofrinhos da Vó Vitória
# ..\database\Colchão
# ..\database\Coleção de Upas
# ..\database\Colheita de Caju
# ..\database\Colorindo
# ..\database\Cometa
# ..\database\Competição de chocolate
# ..\database\Computador
# ..\database\Concatena Dígitos
# ..\database\Concurso
# ..\database\Consecutivos
# ..\database\Construtora
# ..\database\Construção de Rodovia
# ..\database\Conta de água
# ..\database\Contas a pagar
# ..\database\Conversa não tão secreta
# ..\database\Copa
# ..\database\Copa do Mundo
# ..\database\Copa do Mundo_2014
# ..\database\Corredor
# ..\database\Corrida
# ..\database\Corrida_2012
# ..\database\Corrida_2013
# ..\database\Cortando o Papel
# ..\database\Costa
# ..\database\Cubo e quadrado
# ..\database\Cubo Preto
# ..\database\Cubra os Furos
# ..\database\Cálculo
# ..\database\Cápsulas
# ..\database\Câmara de Compensação
# ..\database\Câmeras
# ..\database\Código
# ..\database\Código de compressão
# ..\database\Código_2017
# ..\database\Dança de Formatura
# ..\database\Dança Indígena
# ..\database\Dario e Xerxes
# ..\database\dataset-questions-obi-csbc-semish.zip
# ..\database\dataset-questions-obi.zip
# ..\database\Decifra
# ..\database\Dengue
# ..\database\Dentista
# ..\database\Desafio cartográfico
# ..\database\Desafio do maior número
# ..\database\Detectando Colisões
# ..\database\Detetive
# ..\database\Diagonal
# ..\database\Dieta
# ..\database\Direção
# ..\database\Distância de Manhattan
# ..\database\Distância entre amigos
# ..\database\Dividindo o império
# ..\database\Divisão do Tesouro
# ..\database\Dobradura
# ..\database\Dominó
# ..\database\Dominó Nlogônico
# ..\database\Dominó_2019
# ..\database\Dona Formiga
# ..\database\Dona Lesma
# ..\database\Dona Minhoca
# ..\database\Dona Minhoca_2022
# ..\database\Drone de Entrega
# ..\database\Duende Perdido
# ..\database\Duplas de tênis
# ..\database\Dígitos
# ..\database\Elevador
# ..\database\Elevador_2018
# ..\database\Emoticons
# ..\database\Empregos de Júlio
# ..\database\Energia
# ..\database\Entrega de Caixas
# ..\database\Entrevistas de emprego
# ..\database\Epidemia
# ..\database\Escada perfeita
# ..\database\Escada Rolante
# ..\database\Escadaria
# ..\database\Escadinha
# ..\database\Escalonamento ótimo
# ..\database\Escher
# ..\database\Estoque
# ..\database\Estrada
# ..\database\Estágio
# ..\database\Etiquetas
# ..\database\Exploração do Capitão Levi
# ..\database\Expressões
# ..\database\Falha de segurança
# ..\database\Falta uma
# ..\database\Família real
# ..\database\Famílias de Troia
# ..\database\Fast-Food
# ..\database\Fechadura
# ..\database\Feira de Artesanato
# ..\database\Feira de Bactérias
# ..\database\Feirinha de Artesanato
# ..\database\Festa Junina
# ..\database\Festa olímpica
# ..\database\Figurinhas da copa
# ..\database\Fila
# ..\database\Fila_2015
# ..\database\Fila_2025
# ..\database\Fissura Perigosa
# ..\database\Fita Colorida
# ..\database\Fitas Verde-amarelas
# ..\database\Floresta
# ..\database\Flíper
# ..\database\Forja de ORicalco
# ..\database\Fotografia
# ..\database\Fotos de Relíquias
# ..\database\Frequencia na aula
# ..\database\Frequência
# ..\database\Frete
# ..\database\Frete da Família Silva
# ..\database\Frota de Táxi
# ..\database\Fuga
# ..\database\Fuga com helicóptero
# ..\database\Fusões
# ..\database\Game Show
# ..\database\Game-10
# ..\database\Gangorra
# ..\database\Garamana
# ..\database\Garçom
# ..\database\Gincana
# ..\database\Gincana_2016
# ..\database\Gomoku
# ..\database\Grand Prix da Nlogônia
# ..\database\Grupos de Trabalho
# ..\database\Gráfico de Barras
# ..\database\Guerra por território
# ..\database\Harmonia Nasal
# ..\database\Hidrovias e Rodovias
# ..\database\Hotel
# ..\database\Hotel Nlogônia
# ..\database\Idade de Camila
# ..\database\Ilhas
# ..\database\Imagens de Satélite
# ..\database\Impedido!
# ..\database\Insensibilidade
# ..\database\Intervalo Distinto
# ..\database\Irmãos
# ..\database\Janela
# ..\database\Jardim de infância
# ..\database\Jogo
# ..\database\Jogo da Memória
# ..\database\Jogo da Vida
# ..\database\Jogo de Búzios
# ..\database\Jogo de Cartas
# ..\database\Jogo de Dominós
# ..\database\Jogo de par ou ímpar
# ..\database\Jogo de Pratos
# ..\database\Jogo de Tabuleiro
# ..\database\Jogo do Poder
# ..\database\Jogo do Preto e Branco
# ..\database\Jogo dos copos
# ..\database\Jogo dos Pinos
# ..\database\Labirinto
# ..\database\Lanche na empresa
# ..\database\Leilão
# ..\database\Lençol
# ..\database\Letras
# ..\database\Letras_2015
# ..\database\Linhas Cruzadas
# ..\database\Linhas de Ônibus
# ..\database\Lista de Chamada
# ..\database\Lobo Mau
# ..\database\Loteria
# ..\database\Lâmpadas
# ..\database\Lâmpadas do hotel
# ..\database\Língua do P
# ..\database\Macaco-prego
# ..\database\Macacos me mordam!
# ..\database\Maior valor
# ..\database\Mancha
# ..\database\Manchas de pele
# ..\database\Mania de Ímpar
# ..\database\Mapa
# ..\database\Mapa_2017
# ..\database\Maratona
# ..\database\Margaridas
# ..\database\Matriz Escada
# ..\database\Matriz super-legal
# ..\database\Maximin
# ..\database\Medalhas
# ..\database\Mesa redonda
# ..\database\Meteoros
# ..\database\Metrô da Nlogônia
# ..\database\Metrônibus
# ..\database\Mina
# ..\database\Mini Calculadora
# ..\database\Mini-Poker
# ..\database\model_problem.json
# ..\database\Monopólio
# ..\database\Montanha
# ..\database\Multiplicação de matrizes
# ..\database\Muro
# ..\database\Museu
# ..\database\Musical
# ..\database\Média e mediana
# ..\database\Móbile
# ..\database\Móbile_2015
# ..\database\Música para Todos
# ..\database\Nota cortada
# ..\database\Nota esquecida
# ..\database\Notas
# ..\database\Notas da Prova
# ..\database\Nova avenida
# ..\database\Número de Envelopes
# ..\database\Número de Erdos
# ..\database\O Banco Inteligente
# ..\database\O Chefe
# ..\database\O Fugitivo
# ..\database\O mar não está para peixe
# ..\database\O Tabuleiro Esburacado
# ..\database\OBI
# ..\database\Oficina Mecânica
# ..\database\Ogro
# ..\database\Ogros
# ..\database\Ogro_2024
# ..\database\Olimpíadas
# ..\database\Orkut
# ..\database\Ortografia
# ..\database\Overflow
# ..\database\Paciente Zero
# ..\database\PacMan
# ..\database\Palavras Cruzadas
# ..\database\Palavras Cruzadas_2020
# ..\database\Palíndrome
# ..\database\Pandemia
# ..\database\Pangrama
# ..\database\Par ou ímpar
# ..\database\Parcelamento sem juros
# ..\database\Pares de números
# ..\database\Passa Bolinha
# ..\database\Passatempo
# ..\database\Pastas
# ..\database\Pedido de Desculpas
# ..\database\Pedágio
# ..\database\Pedágio_2010
# ..\database\Penalidade mínima
# ..\database\Pesos
# ..\database\Peça Perdida
# ..\database\Pilhas de moedas
# ..\database\Piloto Automático
# ..\database\Pirâmide
# ..\database\Pirâmide_2018
# ..\database\Pirâmide_2023
# ..\database\Piso da escola
# ..\database\Pizza
# ..\database\Pizza da OBI
# ..\database\Pizzaria
# ..\database\Placar do Jogo
# ..\database\Placas de Carro
# ..\database\Plano de estacionamento
# ..\database\Plano de Internet
# ..\database\Plantação
# ..\database\Plantação de morango
# ..\database\Pneu
# ..\database\Polígono
# ..\database\Ponto do meio
# ..\database\Postes
# ..\database\Prefixo
# ..\database\problems_of_the_obi.txt
# ..\database\Progressões Aritméticas
# ..\database\Projeto Genoma
# ..\database\Promoção de Primeira
# ..\database\Proteja sua senha
# ..\database\Prêmio
# ..\database\Prêmio do Milhão
# ..\database\Pulo do Gato
# ..\database\Pulo do Sapo
# ..\database\Pão a Metro
# ..\database\Pô, que mão
# ..\database\Quadradinho de 8
# ..\database\Quadrado
# ..\database\Quadrado Aritmético
# ..\database\Quadrado Mágico
# ..\database\Quadrado Mágico_2007
# ..\database\Quadrado Mágico_2011
# ..\database\Quadrado Mágico_2022
# ..\database\Quadrado_2022
# ..\database\Quase primo
# ..\database\Quebra-cabeça
# ..\database\Quebra-cabeças
# ..\database\Quermesse
# ..\database\Ralouim
# ..\database\Recarga
# ..\database\Receita de Bolo
# ..\database\Recibo de Compra
# ..\database\Rede Social
# ..\database\Rede ótica
# ..\database\Redes de Descanso
# ..\database\Reduzindo detalhes em um mapa
# ..\database\Relógio
# ..\database\Relógio de Atleta
# ..\database\Relógios
# ..\database\Remove Dígitos
# ..\database\Repositórios
# ..\database\Restaurante
# ..\database\Restaurante de pizza
# ..\database\Retas
# ..\database\Retângulo
# ..\database\Reunião
# ..\database\RoboCoffee
# ..\database\Robô
# ..\database\Robô_2021
# ..\database\Rodovia
# ..\database\Rodovia_2022
# ..\database\Sacolas
# ..\database\Sacoleiro
# ..\database\Salada de Frutas
# ..\database\Saldo de gols
# ..\database\Saldo do Vovô
# ..\database\Sanduíche
# ..\database\Sanduíche_2021
# ..\database\SEDEX
# ..\database\Sedex Marciano
# ..\database\Segredo do Cofre
# ..\database\Selos
# ..\database\Semente
# ..\database\Sequência
# ..\database\Sequência Secreta
# ..\database\Seqüências
# ..\database\Setas
# ..\database\Show
# ..\database\Simulador
# ..\database\Sinuca
# ..\database\Soma
# ..\database\Soma das casas
# ..\database\Soma de Frações
# ..\database\Sorvete
# ..\database\Sr. Sapo
# ..\database\Sr. Toupeira
# ..\database\Sub-seqüências
# ..\database\Subcadeias
# ..\database\Subsequência
# ..\database\Supermercado
# ..\database\Supermercado_2019
# ..\database\Tabela do campeonato
# ..\database\Tacos de bilhar
# ..\database\Tacógrafo
# ..\database\Tanque de combustível
# ..\database\Tapetes
# ..\database\Tarzan
# ..\database\Taxa
# ..\database\Teclado
# ..\database\Telefone
# ..\database\Teleférico
# ..\database\Telemarketing
# ..\database\Telescópio
# ..\database\Temperatura Lunar
# ..\database\Tempo de resposta
# ..\database\Tesouro
# ..\database\Teste de redação
# ..\database\Tetris
# ..\database\Times
# ..\database\Times_2016
# ..\database\Tira-teima
# ..\database\Tiro ao Alvo
# ..\database\Toca do Saci
# ..\database\Tomadas
# ..\database\Torneio
# ..\database\Torneio de tênis
# ..\database\Torre
# ..\database\Torre de dados
# ..\database\Torres de Hanói
# ..\database\Toupeira
# ..\database\Tradutor alienígena
# ..\database\Transmissão de Energia
# ..\database\Transporte de Contêineres
# ..\database\Transportes
# ..\database\Trem da mina
# ..\database\Trilhas
# ..\database\Trio de Bonecas
# ..\database\Trio de Palitinhos
# ..\database\Triângulo
# ..\database\Triângulos
# ..\database\Troca
# ..\database\Troco
# ..\database\Troféu
# ..\database\Truco
# ..\database\Três por Dois
# ..\database\TV da Vovó
# ..\database\Uiquipédia
# ..\database\Um Desafio Muito Distinto
# ..\database\VAR
# ..\database\Vende-se
# ..\database\Vestibular
# ..\database\Viagem
# ..\database\Viagem Espacial
# ..\database\Vice-campeão
# ..\database\Vira!
# ..\database\Visita entre cidades
# ..\database\Vivo ou Morto
# ..\database\Volume da TV
# ..\database\Wifi
# ..\database\Xadrez
# ..\database\Xadrez Aleatório
# ..\database\Zero para cancelar
# ..\database\Zip
# ..\database\Álbum da copa
# ..\database\Álbum de fotos
# ..\database\Ônibus

# %%
for problem in problems:
    print(problem["title"])
# Out:
# A idade de Dona Mônica
# Acelerador de partículas
# Aeroporto
# Alfabeto Alienígena
# Altas Aventuras
# Amigos
# Aplicativo de Calorias
# Arara!
# Arco e flecha
# Arquivos
# Arranha-céu
# Atlanta
# Atletismo
# Auto Estrada
# Autorama
# Avenida
# Avião
# Aviões de papel
# Ações da Bolsa
# Bactérias
# Bafo
# Baldes
# Balé
# Banco
# Banda
# Baralho
# Barcos da Nlogônia
# Basquete de robôs
# Batalha
# Batalha Naval
# Bingo!
# Bits
# Bits Trocados
# Blefe
# Bolas
# Bomba
# Bombom
# Bondinho
# Botas Trocadas
# Brigadeiros
# Burocracia
# Busca na Internet
# Cabo de guerra
# Cachecol da Vovó Vitória
# Cadeado
# Cadeiras do auditório
# Cafeteria
# Café com Leite
# Caixeiro Viajante
# Caixinha de palitos
# Calculadora
# Calculando
# Calçada Imperial
# Caminho
# Caminho das Pontes
# Caminhos do reino
# Camisetas da Olimpíada
# Campeonato
# Campeonato
# Campo de Minhocas
# Campo Minado
# Candidatas
# Capitais
# Capital
# Caravana
# Carga Pesada
# Carnaval
# Carrinho
# Carro elétrico
# Cartas
# Casamento de inteiros
# Castelos da Nlogônia
# Catálogo de Músicas
# Cavalos
# Caverna de Ordinskaya
# Caça ao Tesouro
# Caça ao Tesouro
# Caçadores de Mitos
# Chaves
# Chinelos
# Chocolate
# Chocolate em barra
# Chocolate
# Chuva
# Chuva
# Chuva
# Chuva
# Chuva
# Ciclovias
# Cifra da Nlogônia
# Cinco
# Cinema
# Clube dos Cinco
# Cobertura para Celular
# Cobra coral
# Cofrinhos da Vó Vitória
# Colchão
# Coleção de Upas
# Colheita de Caju
# Colorindo
# Cometa
# Competição de chocolate
# Computador
# Concatena Dígitos
# Concurso
# Consecutivos
# Construtora
# Construção de Rodovia
# Conta de água
# Contas a pagar
# Conversa não tão secreta
# Copa
# Copa do Mundo
# Copa do Mundo
# Corredor
# Corrida
# Corrida
# Corrida
# Cortando o Papel
# Costa
# Cubo e quadrado
# Cubo Preto
# Cubra os Furos
# Cálculo
# Cápsulas
# Câmara de Compensação
# Câmeras
# Código
# Código de Compressão
# Código
# Dança de Formatura
# Dança Indígena
# Dario e Xerxes
# Decifra
# Dengue
# Dentista
# Desafio cartográfico
# Desafio do maior número
# Detectando Colisões
# Detetive
# Diagonal
# Dieta
# Direção
# Distância de Manhattan
# Distância entre amigos
# Dividindo o império
# Divisão do Tesouro
# Dobradura
# Dominó
# Dominó Nlogônico
# Dominó
# Dona Formiga
# Dona Lesma
# Dona Minhoca
# Dona Minhoca
# Drone de Entrega
# Duende Perdido
# Duplas de tênis
# Dígitos
# Elevador
# Elevador
# Emoticons
# Empregos de Júlio
# Energia
# Entrega de Caixas
# Entrevistas de emprego
# Epidemia
# Escada perfeita
# Escada Rolante
# Escadaria
# Escadinha
# Escalonamento ótimo
# Escher
# Estoque
# Estrada
# Estágio
# Etiquetas
# Exploração do Capitão Levi
# Expressões
# Falha de segurança
# Falta uma
# Família real
# Famílias de Troia
# Fast-Food
# Fechadura
# Feira de Artesanato
# Feira de Bactérias
# Feirinha de Artesanato
# Festa Junina
# Festa olímpica
# Figurinhas da copa
# Fila
# Fila
# Fila
# Fissura Perigosa
# Fita Colorida
# Fitas Verde-amarelas
# Floresta
# Flíper
# Forja de ORicalco
# Fotografia
# Fotos de Relíquias
# Frequencia na aula
# Frequência
# Frete
# Frete da Família Silva
# Frota de Táxi
# Fuga
# Fuga com helicóptero
# Fusões
# Game Show
# Game-10
# Gangorra
# Garamana
# Garçom
# Gincana
# Gincana
# Gomoku
# Grand Prix da Nlogônia
# Grupos de Trabalho
# Gráfico de Barras
# Guerra por território
# Harmonia Nasal
# Hidrovias e Rodovias
# Hotel
# Hotel Nlogônia
# Idade de Camila
# Ilhas
# Imagens de Satélite
# Impedido!
# Insensibilidade
# Intervalo Distinto
# Irmãos
# Janela
# Jardim de infância
# Jogo
# Jogo da Memória
# Jogo da Vida
# Jogo de Búzios
# Jogo de Cartas
# Jogo de Dominós
# Jogo de par ou ímpar
# Jogo de Pratos
# Jogo de Tabuleiro
# Jogo do Poder
# Jogo do Preto e Branco
# Jogo dos copos
# Jogo dos Pinos
# Labirinto
# Lanche na empresa
# Leilão
# Lençol
# Letras
# Letras
# Linhas Cruzadas
# Linhas de Ônibus
# Lista de Chamada
# Lobo Mau
# Loteria
# Lâmpadas
# Lâmpadas do hotel
# Língua do P
# Macaco-prego
# Macacos me mordam!
# Maior valor
# Mancha
# Manchas de pele
# Mania de Ímpar
# Mapa
# Mapa
# Maratona
# Margaridas
# Matriz Escada
# Matriz super-legal
# Maximin
# Medalhas
# Mesa redonda
# Meteoros
# Metrô da Nlogônia
# Metrônibus
# Mina
# Mini Calculadora
# Mini-Poker
# Monopólio
# Montanha
# Multiplicação de matrizes
# Muro
# Museu
# Musical
# Média e mediana
# Móbile
# Móbile
# Música para Todos
# Nota cortada
# Nota esquecida
# Notas
# Notas da Prova
# Nova avenida
# Número de Envelopes
# Número de Erdos
# O Banco Inteligente
# O Chefe
# O Fugitivo
# O mar não está para peixe
# O Tabuleiro Esburacado
# OBI
# Oficina Mecânica
# Ogro
# Ogros
# Ogro
# Olimpíadas
# Orkut
# Ortografia
# Overflow
# Paciente Zero
# PacMan
# Palavras Cruzadas
# Palavras Cruzadas
# Palíndrome
# Pandemia
# Pangrama
# Par ou ímpar
# Parcelamento sem juros
# Pares de números
# Passa Bolinha
# Passatempo
# Pastas
# Pedido de Desculpas
# Pedágio
# Pedágio
# Penalidade mínima
# Pesos
# Peça Perdida
# Pilhas de moedas
# Piloto Automático
# Pirâmide
# Pirâmide
# Pirâmide
# Piso da escola
# Pizza
# Pizza da OBI
# Pizzaria
# Placar do Jogo
# Placas de Carro
# Plano de estacionamento
# Plano de Internet
# Plantação
# Plantação de morango
# Pneu
# Polígono
# Ponto do meio
# Postes
# Prefixo
# Progressões Aritméticas
# Projeto Genoma
# Promoção de Primeira
# Proteja sua senha
# Prêmio
# Prêmio do Milhão
# Pulo do Gato
# Pulo do Sapo
# Pão a Metro
# Pô, que mão
# Quadradinho de 8
# Quadrado
# Quadrado Aritmético
# Quadrado Mágico
# Quadrado Mágico
# Quadrado Mágico
# Quadrado Mágico
# Quadrado
# Quase primo
# Quebra-cabeça
# Quebra-cabeças
# Quermesse
# Ralouim
# Recarga
# Receita de Bolo
# Recibo de Compra
# Rede social
# Rede ótica
# Redes de Descanso
# Reduzindo detalhes em um mapa
# Relógio
# Relógio de Atleta
# Relógios
# Remove Dígitos
# Repositórios
# Restaurante
# Restaurante de pizza
# Retas
# Retângulo
# Reunião
# RoboCoffee
# Robô
# Robô
# Rodovia
# Rodovia
# Sacolas
# Sacoleiro
# Salada de Frutas
# Saldo de gols
# Saldo do Vovô
# Sanduíche
# Sanduíche
# SEDEX
# Sedex Marciano
# Segredo do Cofre
# Selos
# Semente
# Sequência
# Sequência Secreta
# Seqüências
# Setas
# Show
# Simulador
# Sinuca
# Soma
# Soma das casas
# Soma de Frações
# Sorvete
# Sr. Sapo
# Sr. Toupeira
# Sub-seqüências
# Subcadeias
# Subsequência
# Supermercado
# Supermercado
# Tabela do campeonato
# Tacos de bilhar
# Tacógrafo
# Tanque de combustível
# Tapetes
# Tarzan
# Taxa
# Teclado
# Telefone
# Teleférico
# Telemarketing
# Telescópio
# Temperatura Lunar
# Tempo de resposta
# Tesouro
# Teste de redação
# Tetris
# Times
# Times
# Tira-teima
# Tiro ao Alvo
# Toca do Saci
# Tomadas
# Torneio
# Torneio de tênis
# Torre
# Torre de Dados
# Torres de Hanói
# Toupeira
# Tradutor alienígena
# Transmissão de Energia
# Transporte de Contêineres
# Transportes
# Trem da mina
# Trilhas
# Trio de Bonecas
# Trio de Palitinhos
# Triângulo
# Triângulos
# Troca
# Troco
# Troféu
# Truco
# Três por Dois
# TV da Vovó
# Uiquipédia
# Um Desafio Muito Distinto
# VAR
# Vende-se
# Vestibular
# Viagem
# Viagem Espacial
# Vice-campeão
# Vira!
# Visita entre cidades
# Vivo ou Morto
# Volume da TV
# Wifi
# Xadrez
# Xadrez Aleatório
# Zero para cancelar
# Zip
# Álbum da copa
# Álbum de fotos
# Ônibus

# %%
output_results_model = pd.read_csv("../output/zero_vs_few/results/results_anthropic_claude_sonnet_4_6_python_few.csv")

df_problems = []

for problem in problems:
    name = problem["title"]
    question_dir = Path('../database') / name
    
    if name in list(output_results_model['question_name']):
        if question_dir.exists():
            df_problems.append(problem)
    
df_problems = pd.DataFrame(df_problems)
counts_difficulty = {}

for d in df_problems["difficulty"].unique():
    cases = df_problems[df_problems["difficulty"] == d]
    counts_difficulty[d] = len(cases)
    
print(counts_difficulty)
# Out:
# {'Fácil': 126, 'Médio': 118, 'Difícil': 55}

# %%
X = ["Fácil", "Médio", "Difícil"]
y = [counts_difficulty[x] for x in X]

print(y)
print(X)
plt.figure(figsize=(8, 6))

bar_plot = plt.bar(X, y, color=['green', 'yellow', 'blue'], edgecolor='black')

plt.bar_label(bar_plot, padding=3)

plt.title("Classificação das questões pelo modelo Gemini 3.1pro")
plt.ylabel('Quantidade de Problemas')
plt.show()
# Out:
# [126, 118, 55]
# ['Fácil', 'Médio', 'Difícil']

# %%
questions_by_years = {}

i = 0
for year in df_problems["year"]:
    if questions_by_years.get(year) is None:
        questions_by_years[year] = []
    
    questions_by_years[year].append(i)
    i += 1
        
for key, count in questions_by_years.items():
    print(f"{key}: {len(count)} quantidades")

names_2015 = []

for index in questions_by_years["2015"]:
    names_2015.append(df_problems.iloc[index]["title"])

print(names_2015)
# Out:
# 2019: 25 quantidades
# 2002: 3 quantidades
# 2010: 6 quantidades
# 2024: 24 quantidades
# 2020: 14 quantidades
# 2016: 22 quantidades
# 2015: 14 quantidades
# 2017: 23 quantidades
# 2018: 28 quantidades
# 2011: 10 quantidades
# 2012: 15 quantidades
# 2021: 22 quantidades
# 2023: 25 quantidades
# 2014: 23 quantidades
# 2022: 24 quantidades
# 2001: 5 quantidades
# 2009: 2 quantidades
# 2013: 8 quantidades
# 2008: 1 quantidades
# 2025: 1 quantidades
# 1999: 1 quantidades
# 2006: 1 quantidades
# 2007: 1 quantidades
# 2003: 1 quantidades
# ['Arquivos', 'Capitais', 'Chocolate em barra', 'Cobra coral', 'Cálculo', 'Código', 'Família real', 'Fila', 'Fita Colorida', 'Letras', 'Mina', 'Prêmio do Milhão', 'Quebra-cabeça', 'Torre']

# %% [markdown]
# ### ZERO-SHOT vs FEW-SHOT
# ---

# %%
files_path = Path("../output/zero_vs_few/results/")
dataset = {}
configs = ['_python_few', '_python_zero', '_cpp_few', '_cpp_zero']

for config in configs:
    for path in files_path.rglob('*'):
        if not path.is_file():
            continue

        parts = str(path).split("results_")
        if len(parts) < 2:
            continue

        model = parts[1]
        #print(model)
        data = pd.read_csv(path)

        df_name_2015 = pd.DataFrame()

        for i, name in enumerate(data["question_name"]):
            if name.split("_2015")[0] in names_2015:
                df_name_2015 = pd.concat([df_name_2015, data.iloc[[i]]])

        if not df_name_2015.empty:
            dataset[model] = df_name_2015

count = 0
for data in dataset["gpt_5_4_python_few.csv"]["total_test_cases"]:
    count += data

print(f"Total de casos de teste: {count}")
# Out:
# Total de casos de teste: 481

# %%
rows = []
for model, data in dataset.items():
    rows.append({
        "Modelo": model,
        "AC":  data["AC"].sum()  / count,
        "WA":  data["WA"].sum()  / count,
        "RE":  data["RE"].sum()  / count,
        "TLE": data["TLE"].sum() / count,
        "CE":  data["CE"].sum()  / count,
    })

df_results = pd.DataFrame(rows)

display(
    df_results.style
    .format({
        "AC":  "{:.2%}",
        "WA":  "{:.2%}",
        "RE":  "{:.2%}",
        "TLE": "{:.2%}",
        "CE":  "{:.2%}",
    })
)
# Out:
# <style type="text/css">
# </style>
# <table id="T_4a3c8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4a3c8_level0_col0" class="col_heading level0 col0" >Modelo</th>
#       <th id="T_4a3c8_level0_col1" class="col_heading level0 col1" >AC</th>
#       <th id="T_4a3c8_level0_col2" class="col_heading level0 col2" >WA</th>
#       <th id="T_4a3c8_level0_col3" class="col_heading level0 col3" >RE</th>
#       <th id="T_4a3c8_level0_col4" class="col_heading level0 col4" >TLE</th>
#       <th id="T_4a3c8_level0_col5" class="col_heading level0 col5" >CE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4a3c8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4a3c8_row0_col0" class="data row0 col0" >anthropic_claude_sonnet_4_6_cpp_few.csv</td>
#       <td id="T_4a3c8_row0_col1" class="data row0 col1" >70.06%</td>
#       <td id="T_4a3c8_row0_col2" class="data row0 col2" >11.85%</td>
#       <td id="T_4a3c8_row0_col3" class="data row0 col3" >0.00%</td>
#       <td id="T_4a3c8_row0_col4" class="data row0 col4" >2.70%</td>
#       <td id="T_4a3c8_row0_col5" class="data row0 col5" >6.24%</td>
#     </tr>
#     <tr>
#       <th id="T_4a3c8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4a3c8_row1_col0" class="data row1 col0" >anthropic_claude_sonnet_4_6_cpp_zero.csv</td>
#       <td id="T_4a3c8_row1_col1" class="data row1 col1" >57.38%</td>
#       <td id="T_4a3c8_row1_col2" class="data row1 col2" >19.33%</td>
#       <td id="T_4a3c8_row1_col3" class="data row1 col3" >0.00%</td>
#       <td id="T_4a3c8_row1_col4" class="data row1 col4" >0.00%</td>
#       <td id="T_4a3c8_row1_col5" class="data row1 col5" >14.14%</td>
#     </tr>
#     <tr>
#       <th id="T_4a3c8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4a3c8_row2_col0" class="data row2 col0" >anthropic_claude_sonnet_4_6_python_few.csv</td>
#       <td id="T_4a3c8_row2_col1" class="data row2 col1" >72.77%</td>
#       <td id="T_4a3c8_row2_col2" class="data row2 col2" >21.00%</td>
#       <td id="T_4a3c8_row2_col3" class="data row2 col3" >6.24%</td>
#       <td id="T_4a3c8_row2_col4" class="data row2 col4" >0.00%</td>
#       <td id="T_4a3c8_row2_col5" class="data row2 col5" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_4a3c8_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_4a3c8_row3_col0" class="data row3 col0" >anthropic_claude_sonnet_4_6_python_zero.csv</td>
#       <td id="T_4a3c8_row3_col1" class="data row3 col1" >54.89%</td>
#       <td id="T_4a3c8_row3_col2" class="data row3 col2" >8.52%</td>
#       <td id="T_4a3c8_row3_col3" class="data row3 col3" >27.44%</td>
#       <td id="T_4a3c8_row3_col4" class="data row3 col4" >0.00%</td>
#       <td id="T_4a3c8_row3_col5" class="data row3 col5" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_4a3c8_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_4a3c8_row4_col0" class="data row4 col0" >deepseek_deepseek_v3_2_cpp_few.csv</td>
#       <td id="T_4a3c8_row4_col1" class="data row4 col1" >69.85%</td>
#       <td id="T_4a3c8_row4_col2" class="data row4 col2" >15.59%</td>
#       <td id="T_4a3c8_row4_col3" class="data row4 col3" >2.49%</td>
#       <td id="T_4a3c8_row4_col4" class="data row4 col4" >2.91%</td>
#       <td id="T_4a3c8_row4_col5" class="data row4 col5" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_4a3c8_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_4a3c8_row5_col0" class="data row5 col0" >deepseek_deepseek_v3_2_cpp_zero.csv</td>
#       <td id="T_4a3c8_row5_col1" class="data row5 col1" >67.98%</td>
#       <td id="T_4a3c8_row5_col2" class="data row5 col2" >16.63%</td>
#       <td id="T_4a3c8_row5_col3" class="data row5 col3" >0.00%</td>
#       <td id="T_4a3c8_row5_col4" class="data row5 col4" >6.24%</td>
#       <td id="T_4a3c8_row5_col5" class="data row5 col5" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_4a3c8_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_4a3c8_row6_col0" class="data row6 col0" >deepseek_deepseek_v3_2_python_few.csv</td>
#       <td id="T_4a3c8_row6_col1" class="data row6 col1" >79.63%</td>
#       <td id="T_4a3c8_row6_col2" class="data row6 col2" >13.51%</td>
#       <td id="T_4a3c8_row6_col3" class="data row6 col3" >0.83%</td>
#       <td id="T_4a3c8_row6_col4" class="data row6 col4" >6.03%</td>
#       <td id="T_4a3c8_row6_col5" class="data row6 col5" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_4a3c8_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_4a3c8_row7_col0" class="data row7 col0" >deepseek_deepseek_v3_2_python_zero.csv</td>
#       <td id="T_4a3c8_row7_col1" class="data row7 col1" >75.26%</td>
#       <td id="T_4a3c8_row7_col2" class="data row7 col2" >9.56%</td>
#       <td id="T_4a3c8_row7_col3" class="data row7 col3" >0.00%</td>
#       <td id="T_4a3c8_row7_col4" class="data row7 col4" >6.03%</td>
#       <td id="T_4a3c8_row7_col5" class="data row7 col5" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_4a3c8_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_4a3c8_row8_col0" class="data row8 col0" >gemini_3_1_pro_preview_cpp_few.csv</td>
#       <td id="T_4a3c8_row8_col1" class="data row8 col1" >84.41%</td>
#       <td id="T_4a3c8_row8_col2" class="data row8 col2" >0.00%</td>
#       <td id="T_4a3c8_row8_col3" class="data row8 col3" >0.00%</td>
#       <td id="T_4a3c8_row8_col4" class="data row8 col4" >6.44%</td>
#       <td id="T_4a3c8_row8_col5" class="data row8 col5" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_4a3c8_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_4a3c8_row9_col0" class="data row9 col0" >gemini_3_1_pro_preview_cpp_zero.csv</td>
#       <td id="T_4a3c8_row9_col1" class="data row9 col1" >90.85%</td>
#       <td id="T_4a3c8_row9_col2" class="data row9 col2" >0.00%</td>
#       <td id="T_4a3c8_row9_col3" class="data row9 col3" >0.00%</td>
#       <td id="T_4a3c8_row9_col4" class="data row9 col4" >0.00%</td>
#       <td id="T_4a3c8_row9_col5" class="data row9 col5" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_4a3c8_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_4a3c8_row10_col0" class="data row10 col0" >gemini_3_1_pro_preview_python_few.csv</td>
#       <td id="T_4a3c8_row10_col1" class="data row10 col1" >100.00%</td>
#       <td id="T_4a3c8_row10_col2" class="data row10 col2" >0.00%</td>
#       <td id="T_4a3c8_row10_col3" class="data row10 col3" >0.00%</td>
#       <td id="T_4a3c8_row10_col4" class="data row10 col4" >0.00%</td>
#       <td id="T_4a3c8_row10_col5" class="data row10 col5" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_4a3c8_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_4a3c8_row11_col0" class="data row11 col0" >gemini_3_1_pro_preview_python_zero.csv</td>
#       <td id="T_4a3c8_row11_col1" class="data row11 col1" >89.60%</td>
#       <td id="T_4a3c8_row11_col2" class="data row11 col2" >0.00%</td>
#       <td id="T_4a3c8_row11_col3" class="data row11 col3" >0.00%</td>
#       <td id="T_4a3c8_row11_col4" class="data row11 col4" >1.25%</td>
#       <td id="T_4a3c8_row11_col5" class="data row11 col5" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_4a3c8_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_4a3c8_row12_col0" class="data row12 col0" >gpt_5_4_cpp_few.csv</td>
#       <td id="T_4a3c8_row12_col1" class="data row12 col1" >76.92%</td>
#       <td id="T_4a3c8_row12_col2" class="data row12 col2" >7.28%</td>
#       <td id="T_4a3c8_row12_col3" class="data row12 col3" >0.00%</td>
#       <td id="T_4a3c8_row12_col4" class="data row12 col4" >6.65%</td>
#       <td id="T_4a3c8_row12_col5" class="data row12 col5" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_4a3c8_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_4a3c8_row13_col0" class="data row13 col0" >gpt_5_4_cpp_zero.csv</td>
#       <td id="T_4a3c8_row13_col1" class="data row13 col1" >67.78%</td>
#       <td id="T_4a3c8_row13_col2" class="data row13 col2" >23.08%</td>
#       <td id="T_4a3c8_row13_col3" class="data row13 col3" >0.00%</td>
#       <t

# %%
def parse_model_name(filename):
    name = filename.replace(".csv", "")
    
    lang = "C++" if "_cpp_" in name else "Python"
    shot = "Few-Shot" if "_few" in name else "Zero-Shot"
    
    # Remove sufixos de config
    model = re.sub(r"_(python|cpp)_(few|zero)$", "", name)
    
    return model, lang, shot

rows = []
for model_file, data in dataset.items():
    model, lang, shot = parse_model_name(model_file)
    rows.append({
        "Modelo": model.replace("_", " "),
        "Linguagem": lang,
        "Prompt": shot,
        "AC":  data["AC"].sum()  / count,
        "WA":  data["WA"].sum()  / count,
        "RE":  data["RE"].sum()  / count,
        "TLE": data["TLE"].sum() / count,
        "CE":  data["CE"].sum()  / count,
    })

df_results = pd.DataFrame(rows)

# %%
pivot = df_results.pivot_table(
    index="Modelo",
    columns=["Linguagem", "Prompt"],
    values="AC"
).round(4)

display(
    pivot.style
    .format("{:.2%}")
)
# Out:
# <style type="text/css">
# </style>
# <table id="T_ca28e">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Linguagem</th>
#       <th id="T_ca28e_level0_col0" class="col_heading level0 col0" colspan="2">C++</th>
#       <th id="T_ca28e_level0_col2" class="col_heading level0 col2" colspan="2">Python</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Prompt</th>
#       <th id="T_ca28e_level1_col0" class="col_heading level1 col0" >Few-Shot</th>
#       <th id="T_ca28e_level1_col1" class="col_heading level1 col1" >Zero-Shot</th>
#       <th id="T_ca28e_level1_col2" class="col_heading level1 col2" >Few-Shot</th>
#       <th id="T_ca28e_level1_col3" class="col_heading level1 col3" >Zero-Shot</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Modelo</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ca28e_level0_row0" class="row_heading level0 row0" >anthropic claude sonnet 4 6</th>
#       <td id="T_ca28e_row0_col0" class="data row0 col0" >70.06%</td>
#       <td id="T_ca28e_row0_col1" class="data row0 col1" >57.38%</td>
#       <td id="T_ca28e_row0_col2" class="data row0 col2" >72.77%</td>
#       <td id="T_ca28e_row0_col3" class="data row0 col3" >54.89%</td>
#     </tr>
#     <tr>
#       <th id="T_ca28e_level0_row1" class="row_heading level0 row1" >deepseek deepseek v3 2</th>
#       <td id="T_ca28e_row1_col0" class="data row1 col0" >69.85%</td>
#       <td id="T_ca28e_row1_col1" class="data row1 col1" >67.98%</td>
#       <td id="T_ca28e_row1_col2" class="data row1 col2" >79.63%</td>
#       <td id="T_ca28e_row1_col3" class="data row1 col3" >75.26%</td>
#     </tr>
#     <tr>
#       <th id="T_ca28e_level0_row2" class="row_heading level0 row2" >gemini 3 1 pro preview</th>
#       <td id="T_ca28e_row2_col0" class="data row2 col0" >84.41%</td>
#       <td id="T_ca28e_row2_col1" class="data row2 col1" >90.85%</td>
#       <td id="T_ca28e_row2_col2" class="data row2 col2" >100.00%</td>
#       <td id="T_ca28e_row2_col3" class="data row2 col3" >89.60%</td>
#     </tr>
#     <tr>
#       <th id="T_ca28e_level0_row3" class="row_heading level0 row3" >gpt 5 4</th>
#       <td id="T_ca28e_row3_col0" class="data row3 col0" >76.92%</td>
#       <td id="T_ca28e_row3_col1" class="data row3 col1" >67.78%</td>
#       <td id="T_ca28e_row3_col2" class="data row3 col2" >76.51%</td>
#       <td id="T_ca28e_row3_col3" class="data row3 col3" >76.09%</td>
#     </tr>
#     <tr>
#       <th id="T_ca28e_level0_row4" class="row_heading level0 row4" >mistralai mistral small 2603</th>
#       <td id="T_ca28e_row4_col0" class="data row4 col0" >37.42%</td>
#       <td id="T_ca28e_row4_col1" class="data row4 col1" >49.27%</td>
#       <td id="T_ca28e_row4_col2" class="data row4 col2" >55.93%</td>
#       <td id="T_ca28e_row4_col3" class="data row4 col3" >50.94%</td>
#     </tr>
#     <tr>
#       <th id="T_ca28e_level0_row5" class="row_heading level0 row5" >stepfun step 3 5 flash free</th>
#       <td id="T_ca28e_row5_col0" class="data row5 col0" >83.99%</td>
#       <td id="T_ca28e_row5_col1" class="data row5 col1" >90.64%</td>
#       <td id="T_ca28e_row5_col2" class="data row5 col2" >97.09%</td>
#       <td id="T_ca28e_row5_col3" class="data row5 col3" >88.15%</td>
#     </tr>
#     <tr>
#       <th id="T_ca28e_level0_row6" class="row_heading level0 row6" >x ai grok code fast 1</th>
#       <td id="T_ca28e_row6_col0" class="data row6 col0" >72.97%</td>
#       <td id="T_ca28e_row6_col1" class="data row6 col1" >70.27%</td>
#       <td id="T_ca28e_row6_col2" class="data row6 col2" >74.43%</td>
#       <td id="T_ca28e_row6_col3" class="data row6 col3" >82.33%</td>
#     </tr>
#     <tr>
#       <th id="T_ca28e_level0_row7" class="row_heading level0 row7" >z ai glm 5</th>
#       <td id="T_ca28e_row7_col0" class="data row7 col0" >83.58%</td>
#       <td id="T_ca28e_row7_col1" class="data row7 col1" >84.20%</td>
#       <td id="T_ca28e_row7_col2" class="data row7 col2" >95.01%</td>
#       <td id="T_ca28e_row7_col3" class="data row7 col3" >79.42%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Top 5 modelos pela média de AC entre todas as configs
top5_models = (
    df_results.groupby("Modelo")["AC"]
    .mean()
    .sort_values(ascending=False)
    .head(5)
    .index
)

df_top5 = df_results[df_results["Modelo"].isin(top5_models)]

fig, ax = plt.subplots(figsize=(12, 6))  # menor pois são só 5 modelos

configs = df_top5[["Linguagem", "Prompt"]].drop_duplicates()
models = top5_models
y = np.arange(len(models))
height = 0.2

for i, (_, cfg) in enumerate(configs.iterrows()):
    subset = df_top5[
        (df_top5["Linguagem"] == cfg.Linguagem) &
        (df_top5["Prompt"] == cfg.Prompt)
    ].set_index("Modelo")["AC"].reindex(models).fillna(0)

    bars = ax.barh(y + i * height, subset * 100, height, label=f"{cfg.Linguagem} / {cfg.Prompt}")

    for bar, val in zip(bars, subset * 100):
        if val > 0:
            ax.text(
                bar.get_width() + 0.5,
                bar.get_y() + bar.get_height() / 2,
                f"{val:.0f}%",
                ha="left", va="center", fontsize=8
            )

ax.set_yticks(y + height * 1.5)
ax.set_yticklabels(models, fontsize=10)
ax.set_xlabel("AC (%)")
ax.set_title("Top 5 Modelos: Taxa de Acerto (AC) por Configuração — OBI 2015 (511 casos de teste)")
ax.legend(title="Config")
ax.set_xlim(0, 120)
ax.grid(False)

plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12, 10))

configs = df_results[["Linguagem", "Prompt"]].drop_duplicates()
models = df_results["Modelo"].unique()


y_indices = np.arange(len(models))
bar_height = 0.2
offset = 0 

for i, (_, cfg) in enumerate(configs.iterrows()):
    subset = df_results[
        (df_results["Linguagem"] == cfg.Linguagem) & 
        (df_results["Prompt"] == cfg.Prompt)
    ].set_index("Modelo")["AC"].reindex(models).fillna(0)
    
    current_y = y_indices + (i * bar_height)
    label_text = f"{cfg.Linguagem} / {cfg.Prompt}"
    
    bars = ax.barh(current_y, subset * 100, bar_height, label=label_text)
    
    for bar in bars:
        width = bar.get_width()
        if width > 0:
            ax.text(
                width + 0.5,
                bar.get_y() + bar.get_height() / 2,
                f"{width:.0f}%", 
                ha="left", 
                va="center", 
                fontsize=8
            )

ax.set_yticks(y_indices + (len(configs) * bar_height) / 2 - (bar_height / 2))
ax.set_yticklabels(models, fontsize=10)
ax.set_xlabel("Taxa de Acerto (%)", fontweight='bold')
ax.set_title("Benchmarking OBI 2015: Taxa de Acerto (AC) por Modelo e Configuração", fontsize=14, pad=20)
ax.set_xlim(0, 110)
ax.legend(title="Configurações (Linguagem / Prompt)", bbox_to_anchor=(1.05, 1), loc='upper left')

plt.grid(axis='x', linestyle='--', alpha=0.4)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Estatísticas do Judge
#
# ---

# %%
def average(data):
    n = len(data)
    count = 0
    
    for value in data:
        count += value
        
    return float(count/n)

# %%
def per_ac_questions(data):
    n = len(data)
    count = 0
    for value in data["judge_predict"]:
        if value == "AC":
            count += 1
            
    return float(count/n)

# %%
files_path = Path("../output/zero_vs_few/results/")

dataset = {}

for path in list(files_path.rglob('*')):        
    model = str(path).split("results_")[1]
    if not "_python_few" in model:
        continue
    
    model = model.split("_python_few")[0]
    
    dataset[model] = pd.read_csv(path)

# %%
metrics = {}

for key, data in dataset.items():
    
    row = {}
    
    hard_questions = data[data["difficulty"] == "Difícil"]
    row['hard_ac'] = per_ac_questions(hard_questions)
    
    medium_questions = data[data["difficulty"] == "Médio"]
    row['medium_ac'] = per_ac_questions(medium_questions)
    
    easy_questions = data[data["difficulty"] == "Fácil"]
    row['easy_ac'] = per_ac_questions(easy_questions)
    
    row['avg_tokens'] = average(data["total_tokens"])
    row['avg_cost'] = average(data["cost_prompt"])
    row['avg_create_code'] = average(data["llm_code_creation_time"])
    
    metrics[key] = row

# %%
rows = []
names_model = {
    "anthropic_claude_sonnet_4_6": "Sonnet 4.6",
    "gpt_5_4": "GPT 5.4",
    "z_ai_glm_5": "GLM 5",
    "deepseek_deepseek_v3_2": "DeepSeek V3.2",
    "x_ai_grok_code_fast_1": "Grok Code Fast 1",
    "stepfun_step_3_5_flash_free": "Step 3.5 Flash Free",
    "gemini_3_1_pro_preview": "Gemini 3.1 Pro",
    "mistralai_mistral_small_2603": "Mistral Small 4"
}

for key, data in metrics.items():
    rows.append({
        "Modelo":               names_model[key],
        "Fácil AC (%)":         data["easy_ac"] * 100,
        "Média AC (%)":         data["medium_ac"] * 100,
        "Difícil AC (%)":       data["hard_ac"] * 100,
        "Tokens (Média)":       data["avg_tokens"],
        "Custo Médio (US$)":    data["avg_cost"],
        "Tempo Médio (s)":      data["avg_create_code"], 
    })

df = pd.DataFrame(rows).sort_values("Modelo").reset_index(drop=True)

display(
    df.style
    .format({
        "Fácil AC (%)":       "{:.2f}",
        "Média AC (%)":       "{:.2f}",
        "Difícil AC (%)":     "{:.2f}",
        "Tokens (Média)":     "{:.0f}",
        "Custo Médio (US$)":  "{:.4f}",
        "Tempo Médio (s)":    "{:.0f}",
    })
    .set_properties(**{'text-align': 'center'})
    .set_table_styles([dict(selector='th', props=[('text-align', 'center')])])
    .hide(axis="index")
)
# Out:
# <style type="text/css">
# #T_e68d7 th {
#   text-align: center;
# }
# #T_e68d7_row0_col0, #T_e68d7_row0_col1, #T_e68d7_row0_col2, #T_e68d7_row0_col3, #T_e68d7_row0_col4, #T_e68d7_row0_col5, #T_e68d7_row0_col6, #T_e68d7_row1_col0, #T_e68d7_row1_col1, #T_e68d7_row1_col2, #T_e68d7_row1_col3, #T_e68d7_row1_col4, #T_e68d7_row1_col5, #T_e68d7_row1_col6, #T_e68d7_row2_col0, #T_e68d7_row2_col1, #T_e68d7_row2_col2, #T_e68d7_row2_col3, #T_e68d7_row2_col4, #T_e68d7_row2_col5, #T_e68d7_row2_col6, #T_e68d7_row3_col0, #T_e68d7_row3_col1, #T_e68d7_row3_col2, #T_e68d7_row3_col3, #T_e68d7_row3_col4, #T_e68d7_row3_col5, #T_e68d7_row3_col6, #T_e68d7_row4_col0, #T_e68d7_row4_col1, #T_e68d7_row4_col2, #T_e68d7_row4_col3, #T_e68d7_row4_col4, #T_e68d7_row4_col5, #T_e68d7_row4_col6, #T_e68d7_row5_col0, #T_e68d7_row5_col1, #T_e68d7_row5_col2, #T_e68d7_row5_col3, #T_e68d7_row5_col4, #T_e68d7_row5_col5, #T_e68d7_row5_col6, #T_e68d7_row6_col0, #T_e68d7_row6_col1, #T_e68d7_row6_col2, #T_e68d7_row6_col3, #T_e68d7_row6_col4, #T_e68d7_row6_col5, #T_e68d7_row6_col6, #T_e68d7_row7_col0, #T_e68d7_row7_col1, #T_e68d7_row7_col2, #T_e68d7_row7_col3, #T_e68d7_row7_col4, #T_e68d7_row7_col5, #T_e68d7_row7_col6 {
#   text-align: center;
# }
# </style>
# <table id="T_e68d7">
#   <thead>
#     <tr>
#       <th id="T_e68d7_level0_col0" class="col_heading level0 col0" >Modelo</th>
#       <th id="T_e68d7_level0_col1" class="col_heading level0 col1" >Fácil AC (%)</th>
#       <th id="T_e68d7_level0_col2" class="col_heading level0 col2" >Média AC (%)</th>
#       <th id="T_e68d7_level0_col3" class="col_heading level0 col3" >Difícil AC (%)</th>
#       <th id="T_e68d7_level0_col4" class="col_heading level0 col4" >Tokens (Média)</th>
#       <th id="T_e68d7_level0_col5" class="col_heading level0 col5" >Custo Médio (US$)</th>
#       <th id="T_e68d7_level0_col6" class="col_heading level0 col6" >Tempo Médio (s)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_e68d7_row0_col0" class="data row0 col0" >DeepSeek V3.2</td>
#       <td id="T_e68d7_row0_col1" class="data row0 col1" >85.71</td>
#       <td id="T_e68d7_row0_col2" class="data row0 col2" >62.71</td>
#       <td id="T_e68d7_row0_col3" class="data row0 col3" >26.23</td>
#       <td id="T_e68d7_row0_col4" class="data row0 col4" >1785</td>
#       <td id="T_e68d7_row0_col5" class="data row0 col5" >0.0007</td>
#       <td id="T_e68d7_row0_col6" class="data row0 col6" >18</td>
#     </tr>
#     <tr>
#       <td id="T_e68d7_row1_col0" class="data row1 col0" >GLM 5</td>
#       <td id="T_e68d7_row1_col1" class="data row1 col1" >95.24</td>
#       <td id="T_e68d7_row1_col2" class="data row1 col2" >88.98</td>
#       <td id="T_e68d7_row1_col3" class="data row1 col3" >65.57</td>
#       <td id="T_e68d7_row1_col4" class="data row1 col4" >7830</td>
#       <td id="T_e68d7_row1_col5" class="data row1 col5" >0.0220</td>
#       <td id="T_e68d7_row1_col6" class="data row1 col6" >115</td>
#     </tr>
#     <tr>
#       <td id="T_e68d7_row2_col0" class="data row2 col0" >GPT 5.4</td>
#       <td id="T_e68d7_row2_col1" class="data row2 col1" >89.68</td>
#       <td id="T_e68d7_row2_col2" class="data row2 col2" >68.64</td>
#       <td id="T_e68d7_row2_col3" class="data row2 col3" >40.98</td>
#       <td id="T_e68d7_row2_col4" class="data row2 col4" >1499</td>
#       <td id="T_e68d7_row2_col5" class="data row2 col5" >0.0065</td>
#       <td id="T_e68d7_row2_col6" class="data row2 col6" >3</td>
#     </tr>
#     <tr>
#       <td id="T_e68d7_row3_col0" class="data row3 col0" >Gemini 3.1 Pro</td>
#       <td id="T_e68d7_row3_col1" class="data row3 col1" >97.62</td>
#       <td id="T_e68d7_row3_col2" class="data row3 col2" >94.92</td>
#       <td id="T_e68d7_row3_col3" class="data row3 col3" >93.44</td>
#       <td id="T_e68d7_row3_col4" class="data row3 col4" >1707</td>
#       <td id="T_e68d7_row3_col5" class="data row3 col5" >0.0061</td>
#       <td id="T_e68d7_row3_col6" class="data row3 col6" >54</td>
#     </tr>
#     <tr>
#       <td id="T_e68d7_row4_col0" class="data row4 col0" >Grok Code Fast 1</td>
#       <td id="T_e68d7_row4_col1" class="data row4 col1" >92.06</td>
#       <td id="T_e68d7_row4_col2" class="data row4 col2" >77.12</td>
#       <td id="T_e68d7_row4_col3" class="data row4 col3" >36.07</td>
#       <td id="T_e68d7_row4_col4" class="data row4 col4" >6939</td>
#       <td id="T_e68d7_row4_col5" class="data row4 col5" >0.0085</td>
#       <td id="T_e68d7_row4_col6" class="data row4 col6" >24</td>
#     </tr>
#     <tr>
#       <td id="T_e68d7_row5_col0" class="data row5 col0" >Mistral Small 4</td>
#       <td id="T_e68d7_row5_col1" class="data row5 col1" >63.49</td>
#       <td id="T_e68d7_row5_col2" class="data row5 col2" >46.61</td>
#       <td id="T_e68d7_row5_col3" class="data row5 col3" >11.48</td>
#       <td id="T_e68d7_row5_col4" class="data row5 col4" >1662</td>
#       <td id="T_e68d7_row5_col5" class="data row5 col5" >0.0004</td>
#       <td id="T_e68d7_row5_col6" class="data row5 col6" >2</td>
#     </tr>
#     <tr>
#       <td id="T_e68d7_row6_col0" class="data row6 col0" >Sonnet 4.6</td>
#       <td id="T_e68d7_row6_col1" class="data row6 col1" >88.89</td>
#       <td id="T_e68d7_row6_col2" class="data row6 col2" >83.05</td>
#       <td id="T_e68d7_row6_col3" class="data row6 col3" >45.90</td>
#       <td id="T_e68d7_row6_col4" class="data row6 col4" >2877</td>
#       <td id="T_e68d7_row6_col5" class="data row6 col5" >0.0237</td>
#       <td id="T_e68d7_row6_col6" class="data row6 col6" >18</td>
#     </tr>
#     <tr>
#       <td id="T_e68d7_row7_col0" class="data row7 col0" >Step 3.5 Flash Free</td>
#       <td id="T_e68d7_row7_col1" class="data row7 col1" >96.83</td>
#       <td id="T_e68d7_row7_col2" class="data row7 col2" >86.44</td>
#       <td id="T_e68d7_row7_col3" class="data row7 col3" >65.57</td>
#       <td id="T_e68d7_row7_col4" class="data row7 col4" >13901</td>
#       <td id="T_e68d7_row7_col5" class="data row7 col5" >0.0054</td>
#       <td id="T_e68d7_row7_col6" class="data row7 col6" >120</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Estatisticas gerais
# ---

# %%
metrics_geral = {}

# %%
metrics_geral["total de tokens"] = {}

for key, data in dataset.items():
    total_tokens_cases = 0

    for count_test in data["total_tokens"]:
        total_tokens_cases += count_test
    
    metrics_geral["total de tokens"][key] = total_tokens_cases
    
    print(f"Total de tokens [{key}]: {total_tokens_cases}")
# Out:
# Total de tokens [anthropic_claude_sonnet_4_6]: 877409
# Total de tokens [deepseek_deepseek_v3_2]: 544573
# Total de tokens [gemini_3_1_pro_preview]: 520516
# Total de tokens [gpt_5_4]: 457127
# Total de tokens [mistralai_mistral_small_2603]: 506877
# Total de tokens [stepfun_step_3_5_flash_free]: 4239921
# Total de tokens [x_ai_grok_code_fast_1]: 2116256
# Total de tokens [z_ai_glm_5]: 2388250

# %%
metrics_geral["tempo de resolução"] = {}

exp_time = 0

for key, data in dataset.items():
    total_time = 0

    for time in data["llm_code_creation_time"]:
        total_time += time
    
    exp_time += total_time
    
    total_time = int(total_time)
    seg = total_time % 60
    total_time = total_time - seg
    total_time = total_time / 60 # total_time em minutos
    
    h = total_time / 60
    min = total_time % 60
    
    metrics_geral["tempo de resolução"][key] = f"{int(h)}h {int(min)} min {seg}s"
    print(f"Tem de resolução das questões pelo modelo {key}: {int(h)}h {int(min)} min {seg}s")

exp_time = int(exp_time)
seg = exp_time % 60
exp_time = exp_time - seg
exp_time = exp_time / 60 # exp_time em minutos
    
h = exp_time / 60
min = exp_time % 60

print(f"Duração total do experimento: {int(h)}h {int(min)} min {seg}s")
# Out:
# Tem de resolução das questões pelo modelo anthropic_claude_sonnet_4_6: 1h 33 min 42s
# Tem de resolução das questões pelo modelo deepseek_deepseek_v3_2: 1h 32 min 26s
# Tem de resolução das questões pelo modelo gemini_3_1_pro_preview: 4h 35 min 28s
# Tem de resolução das questões pelo modelo gpt_5_4: 0h 16 min 5s
# Tem de resolução das questões pelo modelo mistralai_mistral_small_2603: 0h 9 min 59s
# Tem de resolução das questões pelo modelo stepfun_step_3_5_flash_free: 10h 8 min 2s
# Tem de resolução das questões pelo modelo x_ai_grok_code_fast_1: 1h 59 min 45s
# Tem de resolução das questões pelo modelo z_ai_glm_5: 9h 42 min 31s
# Duração total do experimento: 29h 58 min 2s

# %%
total = 0
metrics_geral["total do custo"] = {}

for key, data in dataset.items():
    total_cost = 0

    for count_test in data["cost_prompt"]:
        total_cost += count_test
    
    total += total_cost
    
    metrics_geral["total do custo"][key] = f"U$ {total_cost:.2f}"
    print(f"Total do custo [{key}]: U$ {total_cost:.2f}")
    
print(f"Valor gasto atualmente: U$ {total:.2f}")
# Out:
# Total do custo [anthropic_claude_sonnet_4_6]: U$ 7.22
# Total do custo [deepseek_deepseek_v3_2]: U$ 0.21
# Total do custo [gemini_3_1_pro_preview]: U$ 1.86
# Total do custo [gpt_5_4]: U$ 1.98
# Total do custo [mistralai_mistral_small_2603]: U$ 0.11
# Total do custo [stepfun_step_3_5_flash_free]: U$ 1.65
# Total do custo [x_ai_grok_code_fast_1]: U$ 2.58
# Total do custo [z_ai_glm_5]: U$ 6.72
# Valor gasto atualmente: U$ 22.34

# %%
metrics_geral["no code"] = {}

for key, data in dataset.items():
    no_code = 0

    for judge in data["judge_predict"]:
        if judge == "NO CODE":
            no_code += 1
    
    metrics_geral["no code"][key] = no_code
    print(f"Não produziu código [{key}]: {no_code}")
# Out:
# Não produziu código [anthropic_claude_sonnet_4_6]: 0
# Não produziu código [deepseek_deepseek_v3_2]: 0
# Não produziu código [gemini_3_1_pro_preview]: 0
# Não produziu código [gpt_5_4]: 0
# Não produziu código [mistralai_mistral_small_2603]: 0
# Não produziu código [stepfun_step_3_5_flash_free]: 19
# Não produziu código [x_ai_grok_code_fast_1]: 4
# Não produziu código [z_ai_glm_5]: 10

# %%
rows = []

for model_key in metrics_geral["total de tokens"].keys():
    rows.append({
        "Modelo":               names_model.get(model_key, model_key),
        "Total de Tokens":      metrics_geral["total de tokens"][model_key],
        "Tempo de Resolução":   metrics_geral["tempo de resolução"][model_key],
        "Custo Total":          metrics_geral["total do custo"][model_key],
        "Saída Sem Código":           metrics_geral["no code"][model_key],
    })

df_geral = pd.DataFrame(rows).sort_values("Modelo").reset_index(drop=True)

display(
    df_geral.style
    .format({
        "Total de Tokens": "{:,.0f}",
    })
)
# Out:
# <style type="text/css">
# </style>
# <table id="T_2362c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2362c_level0_col0" class="col_heading level0 col0" >Modelo</th>
#       <th id="T_2362c_level0_col1" class="col_heading level0 col1" >Total de Tokens</th>
#       <th id="T_2362c_level0_col2" class="col_heading level0 col2" >Tempo de Resolução</th>
#       <th id="T_2362c_level0_col3" class="col_heading level0 col3" >Custo Total</th>
#       <th id="T_2362c_level0_col4" class="col_heading level0 col4" >Saída Sem Código</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2362c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2362c_row0_col0" class="data row0 col0" >DeepSeek V3.2</td>
#       <td id="T_2362c_row0_col1" class="data row0 col1" >544,573</td>
#       <td id="T_2362c_row0_col2" class="data row0 col2" >1h 32 min 26s</td>
#       <td id="T_2362c_row0_col3" class="data row0 col3" >U$ 0.21</td>
#       <td id="T_2362c_row0_col4" class="data row0 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_2362c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2362c_row1_col0" class="data row1 col0" >GLM 5</td>
#       <td id="T_2362c_row1_col1" class="data row1 col1" >2,388,250</td>
#       <td id="T_2362c_row1_col2" class="data row1 col2" >9h 42 min 31s</td>
#       <td id="T_2362c_row1_col3" class="data row1 col3" >U$ 6.72</td>
#       <td id="T_2362c_row1_col4" class="data row1 col4" >10</td>
#     </tr>
#     <tr>
#       <th id="T_2362c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2362c_row2_col0" class="data row2 col0" >GPT 5.4</td>
#       <td id="T_2362c_row2_col1" class="data row2 col1" >457,127</td>
#       <td id="T_2362c_row2_col2" class="data row2 col2" >0h 16 min 5s</td>
#       <td id="T_2362c_row2_col3" class="data row2 col3" >U$ 1.98</td>
#       <td id="T_2362c_row2_col4" class="data row2 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_2362c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2362c_row3_col0" class="data row3 col0" >Gemini 3.1 Pro</td>
#       <td id="T_2362c_row3_col1" class="data row3 col1" >520,516</td>
#       <td id="T_2362c_row3_col2" class="data row3 col2" >4h 35 min 28s</td>
#       <td id="T_2362c_row3_col3" class="data row3 col3" >U$ 1.86</td>
#       <td id="T_2362c_row3_col4" class="data row3 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_2362c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_2362c_row4_col0" class="data row4 col0" >Grok Code Fast 1</td>
#       <td id="T_2362c_row4_col1" class="data row4 col1" >2,116,256</td>
#       <td id="T_2362c_row4_col2" class="data row4 col2" >1h 59 min 45s</td>
#       <td id="T_2362c_row4_col3" class="data row4 col3" >U$ 2.58</td>
#       <td id="T_2362c_row4_col4" class="data row4 col4" >4</td>
#     </tr>
#     <tr>
#       <th id="T_2362c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_2362c_row5_col0" class="data row5 col0" >Mistral Small 4</td>
#       <td id="T_2362c_row5_col1" class="data row5 col1" >506,877</td>
#       <td id="T_2362c_row5_col2" class="data row5 col2" >0h 9 min 59s</td>
#       <td id="T_2362c_row5_col3" class="data row5 col3" >U$ 0.11</td>
#       <td id="T_2362c_row5_col4" class="data row5 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_2362c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_2362c_row6_col0" class="data row6 col0" >Sonnet 4.6</td>
#       <td id="T_2362c_row6_col1" class="data row6 col1" >877,409</td>
#       <td id="T_2362c_row6_col2" class="data row6 col2" >1h 33 min 42s</td>
#       <td id="T_2362c_row6_col3" class="data row6 col3" >U$ 7.22</td>
#       <td id="T_2362c_row6_col4" class="data row6 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_2362c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_2362c_row7_col0" class="data row7 col0" >Step 3.5 Flash Free</td>
#       <td id="T_2362c_row7_col1" class="data row7 col1" >4,239,921</td>
#       <td id="T_2362c_row7_col2" class="data row7 col2" >10h 8 min 2s</td>
#       <td id="T_2362c_row7_col3" class="data row7 col3" >U$ 1.65</td>
#       <td id="T_2362c_row7_col4" class="data row7 col4" >19</td>
#     </tr>
#   </tbody>
# </table>

# %%
topics = []

for problem in problems:
    if problem.get("topics") is not None:
        topics.extend(problem["topics"])


print(set(topics))

topics_grafos = ['grafos', 'ciclos em grafos', 'busca em largura', 'busca em profundidade']
topics_pd = ['programação dinâmica']

questions_by_topics = {"g": [], "pd": []}

for name, problem in zip(questions_name, problems):
    topicos = [t.lower() for t in problem.get('topics', [])]
    if any(t in topics_grafos for t in topicos):
        questions_by_topics["g"].append(name)
    elif any(t in topics_pd for t in topicos):
        questions_by_topics["pd"].append(name)

print(questions_by_topics)
print(f"grafos: {len(questions_by_topics['g'])}, programação dinâmica: {len(questions_by_topics['pd'])}")

len_g = len(questions_by_topics['g'])
len_pd = len(questions_by_topics['pd'])

len_g = len(questions_by_topics['g'])
len_pd = len(questions_by_topics['pd'])

data_by_dataset = {}
for key, data in dataset.items():
    data_by_dataset[key] = {'g': 0, 'pd': 0}
    
    df = pd.DataFrame(data)
    df = df[df["judge_predict"] == "AC"]
    
    for _, row in df.iterrows():
        if row["question_name"] in questions_by_topics['g']:
            data_by_dataset[key]['g'] += 1
        elif row["question_name"] in questions_by_topics['pd']:
            data_by_dataset[key]['pd'] += 1

print(data_by_dataset)
print(f"grafos: {len_g}, programação dinâmica: {len_pd}")
# Out:
# {'Greedy', 'estruturas de dados', 'mapeamento', 'divisão e conquista', 'gcd', 'menor caminho', 'lista encadeada', 'fórmulas', 'Lógica', 'algoritmo de dijkstra', 'ordenação', 'lazy propagation', 'convex hull trick', 'Simulação', 'busca em largura', 'conjuntos', 'algoritmos básicos', 'two pointers', 'aritmética', 'guloso', 'busca em profundidade', 'árvore geradora mínima', 'componentes fortemente conexos', '2-sat', 'módulo', 'aho-corasick', 'estruturas condicionais', 'lis', 'sistemas lineares', 'mathematics', 'string', 'matrizes', 'Busca em Profundidade (DFS)', 'mediana', 'geometria básica', 'laços', 'busca', 'geometria', 'Loops', 'caminho mínimo', 'Array', 'lógica', 'busca em largura (bfs)', 'deque', 'exponenciação de matrizes', 'anagramas', 'ciclo', 'Força Bruta', 'pilha', 'prefix sums', 'grafo direcionado', 'autômato celular', 'parsing', 'LCA', 'Vetores', 'tempo', 'vetores', 'contagem', 'prefix sum', 'busca em grafos', 'busca em grade', 'greedy', 'Grafos', 'ad-hoc', 'condicional', 'algoritmos gulosos', 'grafos funcionais', 'grau de vértice', 'busca binária', 'arranjos circulares', 'componentes conexos', 'flood fill', 'brute force', 'básico', 'comparação', 'análise combinatória', 'hashing', 'inversões', 'kadane', 'Busca em Largura', 'árvores', 'matriz', 'ordenação topológica', 'lca', 'soma de prefixos', 'aritmética modular', 'busca exaustiva', 'heap', 'grau de entrada', 'strings', 'array circular', 'intervalos', 'gulosos', 'Mapas', 'algoritmo guloso', 'backtracking', 'busca de padrões', 'knapsack', 'matemática', 'Combinatória', 'Árvore Geradora Mínima', 'condicionais', 'progressão aritmética', 'validação', 'propagação', 'pré-processamento', 'filas de prioridade', 'geometria computacional', 'otimização', 'Pilha', 'teoria dos conjuntos', 'union-find', 'implementação', 'Ad-hoc', 'geometria espacial', 'Geometria Computacional', 'simulação', 'componentes conexas', 'construção', 'priority queue', 'arrays', 'bfs', 'estrutura de dados', 'loops', 'matemática básica', 'fenwick tree', 'floyd-warshall', 'frequência', 'árvore de fenwick', 'permutações', 'dois ponteiros', 'detecção de ciclo', 'mochila', 'teoria dos números', 'Programação Dinâmica', 'mst', 'diâmetro', 'árvore de segmentos', 'Backtracking', 'bitwise', 'somas', 'árvore geradora máxima', 'trie', 'Interseção de Retângulos', 'Algoritmo Guloso', 'manipulação de strings', 'divisão', 'Inclusão-Exclusão', 'distância', 'bipartite', 'Árvores', 'sweepline', 'queries', 'Geometria', 'dp em árvore', 'contagem de frequência', 'sweep line', 'BFS/DFS', 'combinatória', 'recursão', 'ad hoc', 'array', 'frações', 'teoria dos jogos', 'Matemática', 'mdc', 'programação dinâmica', 'subset sum', 'força bruta', 'janela deslizante', 'BFS', 'contagem de inversões', 'matriz de adjacência', 'Estrutura de Dados', 'segment tree', 'dfs', 'criptografia', 'dfs/bfs', 'Strings', 'iteração', 'dijkstra', 'Fila de Prioridade', 'Algoritmo de Kadane', 'somas de prefixo', 'Ordenação Topológica', 'logaritmo', 'Estruturas de Dados', 'números grandes', 'Hashing', 'ordenamento', 'grafos', 'Teoria dos Números', 'set', 'arredondamento', 'consultas'}
# {'g': ['Aeroporto', 'Banda', 'Barcos da Nlogônia', 'Batalha Naval', 'Bomba', 'Caixeiro Viajante', 'Caminho das Pontes', 'Caminhos do reino', 'Capitais', 'Carga Pesada', 'Carro elétrico', 'Castelos da Nlogônia', 'Chuva', 'Chuva_2019', 'Ciclovias', 'Cobertura para Celular', 'Coleção de Upas', 'Colorindo', 'Construção de Rodovia', 'Copa do Mundo_2014', 'Costa', 'Câmara de Compensação', 'Câmeras', 'Dengue', 'Desafio cartográfico', 'Detetive', 'Dividindo o império', 'Dominó', 'Dona Formiga', 'Dona Minhoca', 'Dona Minhoca_2022', 'Duende Perdido', 'Entrevistas de emprego', 'Escalonamento ótimo', 'Família real', 'Famílias de Troia', 'Fast-Food', 'Fissura Perigosa', 'Fitas Verde-amarelas', 'Frete', 'Frete da Família Silva', 'Fuga', 'Fusões', 'Gincana', 'Grand Prix da Nlogônia', 'Hidrovias e Rodovias', 'Ilhas', 'Imagens de Satélite', 'Jogo da Memória', 'Jogo do Poder', 'Jogo do Preto e Branco', 'Labirinto', 'Lanche na empresa', 'Linhas de Ônibus', 'Lobo Mau', 'Mancha', 'Manchas de pele', 'Mapa', 'Mapa_2017', 'Metrô da Nlogônia', 'Metrônibus', 'Mina', 'Museu', 'Número de Erdos', 'O Chefe', 'Orkut', 'Paciente Zero', 'Passa Bolinha', 'Pedágio', 'Penalidade mínima', 'Promoção de Primeira', 'Pulo do Gato', 'Quebra-cabeça', 'Ralouim', 'Recarga', 'Rede ótica', 'Reduzindo detalhes em um mapa', 'Relógios', 'Reunião', 'Rodovia', 'Rodovia_2022', 'Sacoleiro', 'Setas', 'Sr. Sapo', 'Sr. Toupeira', 'Tarzan', 'Tesouro', 'Times_2016', 'Toca do Saci', 'Toupeira', 'Transmissão de Energia', 'Transportes', 'Trem da mina', 'Uiquipédia', 'Viagem', 'Visita entre cidades', 'Wifi', 'Ônibus'], 'pd': ['Altas Aventuras', 'Bits', 'Brigadeiros', 'Cachecol da Vovó Vitória', 'Calçada Imperial', 'Carrinho', 'Catálogo de Músicas', 'Caça ao Tesouro', 'Construtora', 'Corredor', 'Distância entre amigos', 'Dominó Nlogônico', 'Empregos de Júlio', 'Escadaria', 'Etiquetas', 'Fita Colorida', 'Forja de ORicalco', 'Harmonia Nasal', 'Letras_2015', 'Matriz super-legal', 'Muro', 'O Banco Inteligente', 'Ortografia', 'Palíndrome', 'Pedido de Desculpas', 'Pilhas de moedas', 'Pirâmide_2018', 'Pizza', 'Quebra-cabeças', 'Recibo de Compra', 'Remove Dígitos', 'Saldo de gols', 'Sequência', 'Sub-seqüências', 'Subcadeias', 'Taxa', 'Torneio', 'Torre de dados', 'Tradutor alienígena', 'Trio de Bonecas', 'Troco', 'Vira!']}
# grafos: 98, programação dinâmica: 42
# {'anthropic_claude_sonnet_4_6': {'g': 43, 'pd': 16}, 'deepseek_deepseek_v3_2': {'g': 27, 'pd': 11}, 'gemini_3_1_pro_preview': {'g': 59, 'pd': 22}, 'gpt_5_4': {'g': 38, 'pd': 12}, 'mistralai_mistral_small_2603': {'g': 22, 'pd': 5}, 'stepfun_step_3_5_flash_free': {'g': 41, 'pd': 19}, 'x_ai_grok_code_fast_1': {'g': 40, 'pd': 12}, 'z_ai_glm_5': {'g': 48, 'pd': 19}}
# grafos: 98, programação dinâmica: 42

# %%
modelos = list(data_by_dataset.keys())
modelos_sorted = sorted(data_by_dataset.keys(), key=lambda k: data_by_dataset[k]['g'] + data_by_dataset[k]['pd'], reverse=True)
modelos = modelos_sorted
raw_g  = [data_by_dataset[k]['g']  for k in modelos]
raw_pd = [data_by_dataset[k]['pd'] for k in modelos]
g_pct  = [v / (len_g + len_pd) * 100 for v in raw_g]
pd_pct = [v / (len_g + len_pd) * 100 for v in raw_pd]

x = np.arange(len(modelos))
w = 0.55

fig, ax = plt.subplots(figsize=(13, 5))
bars_g  = ax.bar(x, g_pct,  w, label='Grafos',         color='#378ADD')
bars_pd = ax.bar(x, pd_pct, w, label='Prog. dinâmica', color='#1D9E75', bottom=g_pct)

for i in range(len(modelos)):
    # % dentro da barra de grafos
    if g_pct[i] > 3:
        ax.text(x[i], g_pct[i] / 2, f'{g_pct[i]:.1f}%',
                ha='center', va='center', fontsize=8, color='black', fontweight='bold')

    # % dentro da barra de prog. dinâmica
    if pd_pct[i] > 3:
        ax.text(x[i], g_pct[i] + pd_pct[i] / 2, f'{pd_pct[i]:.1f}%',
                ha='center', va='center', fontsize=8, color='black', fontweight='bold')

    # % total acima da barra
    total = g_pct[i] + pd_pct[i]
    ax.text(x[i], total + 1, f'{total:.1f}%',
            ha='center', va='bottom', fontsize=8, color='gray')

ax.set_xticks(x)
ax.set_xticklabels(modelos, rotation=30, ha='right', fontsize=9)
ax.set_ylabel('% de acertos')
ax.set_ylim(0, 100)
ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda v, _: f'{v:.0f}%'))
ax.legend()
ax.grid(axis='y', alpha=0.2)
ax.spines[['top', 'right']].set_visible(False)
plt.tight_layout()
plt.show()
